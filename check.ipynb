# %%
import pandas as pd
import os

base_files_path = 'results/amazon_ratings/logs_base'
base_files = os.listdir(base_files_path)

# %%
list(set([x.split('_')[0] for x in base_files]))
# Out:
# ['GAT', 'GCN', 'TAG', 'GT', 'GAT-sep', 'GT-sep', 'ResNet', 'SAGE']

# %%
from collections import defaultdict
model2scores = defaultdict(list)

# %%
import re

for split in range(10):
    for model in ['GT-sep', 'GAT-sep', 'GAT', 'TAG', 'GCN', 'SAGE', 'GT', 'ResNet']:
        files = [
            x for x in base_files
            if model in x and f'split{split}' in x
        ]
        if len(files) == 0:
            continue
        scores = {}
        for file in files:
            with open(f'{base_files_path}/{file}', 'r') as f:
                content = f.read()
                train_match = re.search(r'train_acc=([\d.]+)', content)
                val_match = re.search(r'val_acc=([\d.]+)', content)
                test_acc_match = re.search(r'test_acc=([\d.]+)', content)
                test_f1m_match = re.search(r'test_f1m=([\d.]+)', content)
                test_f1w_match = re.search(r'test_f1w=([\d.]+)', content)
                test_prec_match = re.search(r'test_prec=([\d.]+)', content)
                test_rec_match = re.search(r'test_rec=([\d.]+)', content)
                test_loss_match = re.search(r'test_loss=([\d.]+)', content)
                scores[file] = {
                    'train_acc': float(train_match.group(1)) if train_match else None,
                    'val_acc': float(val_match.group(1)) if val_match else None,
                    'test_acc': float(test_acc_match.group(1)) if test_acc_match else None,
                    'test_f1m': float(test_f1m_match.group(1)) if test_f1m_match else None,
                    'test_f1w': float(test_f1w_match.group(1)) if test_f1w_match else None,
                    'test_prec': float(test_prec_match.group(1)) if test_prec_match else None,
                    'test_rec': float(test_rec_match.group(1)) if test_rec_match else None,
                    'test_loss': float(test_loss_match.group(1)) if test_loss_match else None
                }
        best_val_acc = 0
        for file, score in scores.items():
            if score['val_acc'] > best_val_acc:
                best_val_acc = score['val_acc']
                best_file = file
        print(f'{model}\t {best_file}\t test acc: {scores[best_file]["test_acc"]}\t stats: {scores[best_file]}')
        model2scores[model + "_BASE"].append(scores[best_file]["test_acc"])
    print()
    print('=' * 100)
    print()
# Out:
# GT-sep	 GT-sep_4L_split0.log	 test acc: 0.5293	 stats: {'train_acc': 0.9472, 'val_acc': 0.5347, 'test_acc': 0.5293, 'test_f1m': 0.4759, 'test_f1w': 0.5253, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1232}
# GAT-sep	 GAT-sep_2L_split0.log	 test acc: 0.5502	 stats: {'train_acc': 0.9888, 'val_acc': 0.5404, 'test_acc': 0.5502, 'test_f1m': 0.501, 'test_f1w': 0.545, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3799}
# GAT	 GAT-sep_2L_split0.log	 test acc: 0.5502	 stats: {'train_acc': 0.9888, 'val_acc': 0.5404, 'test_acc': 0.5502, 'test_f1m': 0.501, 'test_f1w': 0.545, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3799}
# TAG	 TAG_2L_split0.log	 test acc: 0.5203	 stats: {'train_acc': 0.9713, 'val_acc': 0.5135, 'test_acc': 0.5203, 'test_f1m': 0.4699, 'test_f1w': 0.5173, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1664}
# GCN	 GCN_2L_split0.log	 test acc: 0.4916	 stats: {'train_acc': 0.7457, 'val_acc': 0.4929, 'test_acc': 0.4916, 'test_f1m': 0.4308, 'test_f1w': 0.4851, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6063}
# SAGE	 SAGE_2L_split0.log	 test acc: 0.5331	 stats: {'train_acc': 0.994, 'val_acc': 0.5278, 'test_acc': 0.5331, 'test_f1m': 0.4823, 'test_f1w': 0.5276, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5093}
# GT	 GT-sep_4L_split0.log	 test acc: 0.5293	 stats: {'train_acc': 0.9472, 'val_acc': 0.5347, 'test_acc': 0.5293, 'test_f1m': 0.4759, 'test_f1w': 0.5253, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1232}
# ResNet	 ResNet_2L_split0.log	 test acc: 0.4725	 stats: {'train_acc': 0.9088, 'val_acc': 0.4563, 'test_acc': 0.4725, 'test_f1m': 0.414, 'test_f1w': 0.4695, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1023}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_2L_split1.log	 test acc: 0.5316	 stats: {'train_acc': 0.9656, 'val_acc': 0.5349, 'test_acc': 0.5316, 'test_f1m': 0.4802, 'test_f1w': 0.5283, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1745}
# GAT-sep	 GAT-sep_2L_split1.log	 test acc: 0.5403	 stats: {'train_acc': 0.9847, 'val_acc': 0.546, 'test_acc': 0.5403, 'test_f1m': 0.4941, 'test_f1w': 0.5356, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2541}
# GAT	 GAT-sep_2L_split1.log	 test acc: 0.5403	 stats: {'train_acc': 0.9847, 'val_acc': 0.546, 'test_acc': 0.5403, 'test_f1m': 0.4941, 'test_f1w': 0.5356, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2541}
# TAG	 TAG_2L_split1.log	 test acc: 0.5146	 stats: {'train_acc': 0.9764, 'val_acc': 0.5278, 'test_acc': 0.5146, 'test_f1m': 0.4579, 'test_f1w': 0.5112, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2833}
# GCN	 GCN_2L_split1.log	 test acc: 0.4944	 stats: {'train_acc': 0.7398, 'val_acc': 0.4931, 'test_acc': 0.4944, 'test_f1m': 0.4317, 'test_f1w': 0.4894, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5853}
# SAGE	 SAGE_3L_split1.log	 test acc: 0.5341	 stats: {'train_acc': 0.9878, 'val_acc': 0.538, 'test_acc': 0.5341, 'test_f1m': 0.4892, 'test_f1w': 0.5301, 'test_prec': None, 'test_rec': None, 'test_loss': 2.4851}
# GT	 GT_2L_split1.log	 test acc: 0.5349	 stats: {'train_acc': 0.9604, 'val_acc': 0.5365, 'test_acc': 0.5349, 'test_f1m': 0.4851, 'test_f1w': 0.5312, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1148}
# ResNet	 ResNet_1L_split1.log	 test acc: 0.4663	 stats: {'train_acc': 0.8674, 'val_acc': 0.4722, 'test_acc': 0.4663, 'test_f1m': 0.3983, 'test_f1w': 0.4573, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8795}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split2.log	 test acc: 0.5331	 stats: {'train_acc': 0.941, 'val_acc': 0.5314, 'test_acc': 0.5331, 'test_f1m': 0.4707, 'test_f1w': 0.5301, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1513}
# GAT-sep	 GAT-sep_2L_split2.log	 test acc: 0.536	 stats: {'train_acc': 0.9596, 'val_acc': 0.537, 'test_acc': 0.536, 'test_f1m': 0.469, 'test_f1w': 0.5285, 'test_prec': None, 'test_rec': None, 'test_loss': 2.094}
# GAT	 GAT-sep_2L_split2.log	 test acc: 0.536	 stats: {'train_acc': 0.9596, 'val_acc': 0.537, 'test_acc': 0.536, 'test_f1m': 0.469, 'test_f1w': 0.5285, 'test_prec': None, 'test_rec': None, 'test_loss': 2.094}
# TAG	 TAG_1L_split2.log	 test acc: 0.5025	 stats: {'train_acc': 0.9647, 'val_acc': 0.5203, 'test_acc': 0.5025, 'test_f1m': 0.424, 'test_f1w': 0.4924, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1814}
# GCN	 GCN_2L_split2.log	 test acc: 0.4834	 stats: {'train_acc': 0.6914, 'val_acc': 0.4939, 'test_acc': 0.4834, 'test_f1m': 0.4045, 'test_f1w': 0.4765, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5123}
# SAGE	 SAGE_2L_split2.log	 test acc: 0.5277	 stats: {'train_acc': 0.9895, 'val_acc': 0.5287, 'test_acc': 0.5277, 'test_f1m': 0.4632, 'test_f1w': 0.5202, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5156}
# GT	 GT_2L_split2.log	 test acc: 0.5321	 stats: {'train_acc': 0.9574, 'val_acc': 0.5373, 'test_acc': 0.5321, 'test_f1m': 0.4695, 'test_f1w': 0.5288, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1563}
# ResNet	 ResNet_3L_split2.log	 test acc: 0.4682	 stats: {'train_acc': 0.8634, 'val_acc': 0.4659, 'test_acc': 0.4682, 'test_f1m': 0.3944, 'test_f1w': 0.4613, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0383}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_4L_split3.log	 test acc: 0.5146	 stats: {'train_acc': 0.9337, 'val_acc': 0.5327, 'test_acc': 0.5146, 'test_f1m': 0.458, 'test_f1w': 0.5112, 'test_prec': None, 'test_rec': None, 'test_loss': 2.106}
# GAT-sep	 GAT-sep_2L_split3.log	 test acc: 0.5437	 stats: {'train_acc': 0.9681, 'val_acc': 0.543, 'test_acc': 0.5437, 'test_f1m': 0.4729, 'test_f1w': 0.5356, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1593}
# GAT	 GAT-sep_2L_split3.log	 test acc: 0.5437	 stats: {'train_acc': 0.9681, 'val_acc': 0.543, 'test_acc': 0.5437, 'test_f1m': 0.4729, 'test_f1w': 0.5356, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1593}
# TAG	 TAG_2L_split3.log	 test acc: 0.5166	 stats: {'train_acc': 0.9661, 'val_acc': 0.5197, 'test_acc': 0.5166, 'test_f1m': 0.4534, 'test_f1w': 0.5131, 'test_prec': None, 'test_rec': None, 'test_loss': 2.214}
# GCN	 GCN_2L_split3.log	 test acc: 0.4823	 stats: {'train_acc': 0.7302, 'val_acc': 0.4999, 'test_acc': 0.4823, 'test_f1m': 0.413, 'test_f1w': 0.4754, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5861}
# SAGE	 SAGE_2L_split3.log	 test acc: 0.5306	 stats: {'train_acc': 0.9898, 'val_acc': 0.5357, 'test_acc': 0.5306, 'test_f1m': 0.4665, 'test_f1w': 0.5234, 'test_prec': None, 'test_rec': None, 'test_loss': 2.451}
# GT	 GT_3L_split3.log	 test acc: 0.5236	 stats: {'train_acc': 0.9104, 'val_acc': 0.5378, 'test_acc': 0.5236, 'test_f1m': 0.4658, 'test_f1w': 0.5203, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9254}
# ResNet	 ResNet_2L_split3.log	 test acc: 0.4579	 stats: {'train_acc': 0.8664, 'val_acc': 0.464, 'test_acc': 0.4579, 'test_f1m': 0.3882, 'test_f1w': 0.4528, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9486}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_4L_split4.log	 test acc: 0.5318	 stats: {'train_acc': 0.9584, 'val_acc': 0.5399, 'test_acc': 0.5318, 'test_f1m': 0.467, 'test_f1w': 0.529, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2358}
# GAT-sep	 GAT-sep_2L_split4.log	 test acc: 0.5394	 stats: {'train_acc': 0.9802, 'val_acc': 0.546, 'test_acc': 0.5394, 'test_f1m': 0.4741, 'test_f1w': 0.5346, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2487}
# GAT	 GAT-sep_2L_split4.log	 test acc: 0.5394	 stats: {'train_acc': 0.9802, 'val_acc': 0.546, 'test_acc': 0.5394, 'test_f1m': 0.4741, 'test_f1w': 0.5346, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2487}
# TAG	 TAG_2L_split4.log	 test acc: 0.5197	 stats: {'train_acc': 0.9732, 'val_acc': 0.5323, 'test_acc': 0.5197, 'test_f1m': 0.4522, 'test_f1w': 0.5153, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2685}
# GCN	 GCN_2L_split4.log	 test acc: 0.487	 stats: {'train_acc': 0.7431, 'val_acc': 0.4993, 'test_acc': 0.487, 'test_f1m': 0.4108, 'test_f1w': 0.4806, 'test_prec': None, 'test_rec': None, 'test_loss': 1.662}
# SAGE	 SAGE_2L_split4.log	 test acc: 0.5305	 stats: {'train_acc': 0.9939, 'val_acc': 0.5399, 'test_acc': 0.5305, 'test_f1m': 0.4666, 'test_f1w': 0.5241, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5627}
# GT	 GT_2L_split4.log	 test acc: 0.521	 stats: {'train_acc': 0.9517, 'val_acc': 0.5411, 'test_acc': 0.521, 'test_f1m': 0.4572, 'test_f1w': 0.5169, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1272}
# ResNet	 ResNet_1L_split4.log	 test acc: 0.4704	 stats: {'train_acc': 0.8686, 'val_acc': 0.4762, 'test_acc': 0.4704, 'test_f1m': 0.3963, 'test_f1w': 0.462, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8524}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_4L_split5.log	 test acc: 0.529	 stats: {'train_acc': 0.9504, 'val_acc': 0.5278, 'test_acc': 0.529, 'test_f1m': 0.4733, 'test_f1w': 0.5246, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2495}
# GAT-sep	 GAT-sep_2L_split5.log	 test acc: 0.5383	 stats: {'train_acc': 0.9893, 'val_acc': 0.5409, 'test_acc': 0.5383, 'test_f1m': 0.4818, 'test_f1w': 0.5335, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5482}
# GAT	 GAT-sep_2L_split5.log	 test acc: 0.5383	 stats: {'train_acc': 0.9893, 'val_acc': 0.5409, 'test_acc': 0.5383, 'test_f1m': 0.4818, 'test_f1w': 0.5335, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5482}
# TAG	 TAG_2L_split5.log	 test acc: 0.5172	 stats: {'train_acc': 0.9823, 'val_acc': 0.5239, 'test_acc': 0.5172, 'test_f1m': 0.4594, 'test_f1w': 0.5149, 'test_prec': None, 'test_rec': None, 'test_loss': 2.4278}
# GCN	 GCN_3L_split5.log	 test acc: 0.4949	 stats: {'train_acc': 0.7351, 'val_acc': 0.5027, 'test_acc': 0.4949, 'test_f1m': 0.4331, 'test_f1w': 0.4922, 'test_prec': None, 'test_rec': None, 'test_loss': 1.7505}
# SAGE	 SAGE_2L_split5.log	 test acc: 0.5329	 stats: {'train_acc': 0.9907, 'val_acc': 0.5337, 'test_acc': 0.5329, 'test_f1m': 0.4722, 'test_f1w': 0.5262, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5469}
# GT	 GT_3L_split5.log	 test acc: 0.5334	 stats: {'train_acc': 0.9308, 'val_acc': 0.5321, 'test_acc': 0.5334, 'test_f1m': 0.4761, 'test_f1w': 0.5301, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0757}
# ResNet	 ResNet_3L_split5.log	 test acc: 0.4579	 stats: {'train_acc': 0.8616, 'val_acc': 0.4694, 'test_acc': 0.4579, 'test_f1m': 0.3957, 'test_f1w': 0.4542, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9789}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split6.log	 test acc: 0.5296	 stats: {'train_acc': 0.9434, 'val_acc': 0.5421, 'test_acc': 0.5296, 'test_f1m': 0.4731, 'test_f1w': 0.5263, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1317}
# GAT-sep	 GAT-sep_2L_split6.log	 test acc: 0.5406	 stats: {'train_acc': 0.9809, 'val_acc': 0.5468, 'test_acc': 0.5406, 'test_f1m': 0.4891, 'test_f1w': 0.5354, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3122}
# GAT	 GAT-sep_2L_split6.log	 test acc: 0.5406	 stats: {'train_acc': 0.9809, 'val_acc': 0.5468, 'test_acc': 0.5406, 'test_f1m': 0.4891, 'test_f1w': 0.5354, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3122}
# TAG	 TAG_2L_split6.log	 test acc: 0.5123	 stats: {'train_acc': 0.9747, 'val_acc': 0.5231, 'test_acc': 0.5123, 'test_f1m': 0.4574, 'test_f1w': 0.5103, 'test_prec': None, 'test_rec': None, 'test_loss': 2.4111}
# GCN	 GCN_2L_split6.log	 test acc: 0.4867	 stats: {'train_acc': 0.7322, 'val_acc': 0.4921, 'test_acc': 0.4867, 'test_f1m': 0.4148, 'test_f1w': 0.4821, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6258}
# SAGE	 SAGE_2L_split6.log	 test acc: 0.5309	 stats: {'train_acc': 0.9913, 'val_acc': 0.5422, 'test_acc': 0.5309, 'test_f1m': 0.4731, 'test_f1w': 0.5259, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5263}
# GT	 GT-sep_5L_split6.log	 test acc: 0.5296	 stats: {'train_acc': 0.9434, 'val_acc': 0.5421, 'test_acc': 0.5296, 'test_f1m': 0.4731, 'test_f1w': 0.5263, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1317}
# ResNet	 ResNet_2L_split6.log	 test acc: 0.4604	 stats: {'train_acc': 0.8907, 'val_acc': 0.4731, 'test_acc': 0.4604, 'test_f1m': 0.394, 'test_f1w': 0.4563, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0669}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split7.log	 test acc: 0.5238	 stats: {'train_acc': 0.9441, 'val_acc': 0.5305, 'test_acc': 0.5238, 'test_f1m': 0.4653, 'test_f1w': 0.5208, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1112}
# GAT-sep	 GAT-sep_2L_split7.log	 test acc: 0.5373	 stats: {'train_acc': 0.9861, 'val_acc': 0.5339, 'test_acc': 0.5373, 'test_f1m': 0.477, 'test_f1w': 0.5323, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3757}
# GAT	 GAT-sep_2L_split7.log	 test acc: 0.5373	 stats: {'train_acc': 0.9861, 'val_acc': 0.5339, 'test_acc': 0.5373, 'test_f1m': 0.477, 'test_f1w': 0.5323, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3757}
# TAG	 TAG_2L_split7.log	 test acc: 0.5192	 stats: {'train_acc': 0.9815, 'val_acc': 0.518, 'test_acc': 0.5192, 'test_f1m': 0.4621, 'test_f1w': 0.515, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3909}
# GCN	 GCN_2L_split7.log	 test acc: 0.4886	 stats: {'train_acc': 0.7527, 'val_acc': 0.4926, 'test_acc': 0.4886, 'test_f1m': 0.4275, 'test_f1w': 0.4846, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6848}
# SAGE	 SAGE_4L_split7.log	 test acc: 0.5197	 stats: {'train_acc': 0.9424, 'val_acc': 0.5257, 'test_acc': 0.5197, 'test_f1m': 0.4635, 'test_f1w': 0.5154, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0521}
# GT	 GT-sep_5L_split7.log	 test acc: 0.5238	 stats: {'train_acc': 0.9441, 'val_acc': 0.5305, 'test_acc': 0.5238, 'test_f1m': 0.4653, 'test_f1w': 0.5208, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1112}
# ResNet	 ResNet_2L_split7.log	 test acc: 0.4666	 stats: {'train_acc': 0.9048, 'val_acc': 0.4643, 'test_acc': 0.4666, 'test_f1m': 0.402, 'test_f1w': 0.4624, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1537}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_2L_split8.log	 test acc: 0.5185	 stats: {'train_acc': 0.9673, 'val_acc': 0.5342, 'test_acc': 0.5185, 'test_f1m': 0.4604, 'test_f1w': 0.5153, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3364}
# GAT-sep	 GAT-sep_2L_split8.log	 test acc: 0.538	 stats: {'train_acc': 0.9918, 'val_acc': 0.5391, 'test_acc': 0.538, 'test_f1m': 0.4832, 'test_f1w': 0.5328, 'test_prec': None, 'test_rec': None, 'test_loss': 2.4855}
# GAT	 GAT-sep_2L_split8.log	 test acc: 0.538	 stats: {'train_acc': 0.9918, 'val_acc': 0.5391, 'test_acc': 0.538, 'test_f1m': 0.4832, 'test_f1w': 0.5328, 'test_prec': None, 'test_rec': None, 'test_loss': 2.4855}
# TAG	 TAG_1L_split8.log	 test acc: 0.5114	 stats: {'train_acc': 0.9897, 'val_acc': 0.5216, 'test_acc': 0.5114, 'test_f1m': 0.4447, 'test_f1w': 0.503, 'test_prec': None, 'test_rec': None, 'test_loss': 2.5263}
# GCN	 GCN_2L_split8.log	 test acc: 0.481	 stats: {'train_acc': 0.7415, 'val_acc': 0.4976, 'test_acc': 0.481, 'test_f1m': 0.4139, 'test_f1w': 0.4751, 'test_prec': None, 'test_rec': None, 'test_loss': 1.651}
# SAGE	 SAGE_3L_split8.log	 test acc: 0.5161	 stats: {'train_acc': 0.987, 'val_acc': 0.53, 'test_acc': 0.5161, 'test_f1m': 0.4575, 'test_f1w': 0.5101, 'test_prec': None, 'test_rec': None, 'test_loss': 2.645}
# GT	 GT-sep_2L_split8.log	 test acc: 0.5185	 stats: {'train_acc': 0.9673, 'val_acc': 0.5342, 'test_acc': 0.5185, 'test_f1m': 0.4604, 'test_f1w': 0.5153, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3364}
# ResNet	 ResNet_2L_split8.log	 test acc: 0.4653	 stats: {'train_acc': 0.9047, 'val_acc': 0.4718, 'test_acc': 0.4653, 'test_f1m': 0.4026, 'test_f1w': 0.4605, 'test_prec': None, 'test_rec': None, 'test_loss': 2.1186}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_4L_split9.log	 test acc: 0.5223	 stats: {'train_acc': 0.9441, 'val_acc': 0.5342, 'test_acc': 0.5223, 'test_f1m': 0.4666, 'test_f1w': 0.5194, 'test_prec': None, 'test_rec': None, 'test_loss': 2.137}
# GAT-sep	 GAT-sep_2L_split9.log	 test acc: 0.5383	 stats: {'train_acc': 0.9916, 'val_acc': 0.5404, 'test_acc': 0.5383, 'test_f1m': 0.4818, 'test_f1w': 0.534, 'test_prec': None, 'test_rec': None, 'test_loss': 2.4943}
# GAT	 GAT-sep_2L_split9.log	 test acc: 0.5383	 stats: {'train_acc': 0.9916, 'val_acc': 0.5404, 'test_acc': 0.5383, 'test_f1m': 0.4818, 'test_f1w': 0.534, 'test_prec': None, 'test_rec': None, 'test_loss': 2.4943}
# TAG	 TAG_2L_split9.log	 test acc: 0.5243	 stats: {'train_acc': 0.9599, 'val_acc': 0.5176, 'test_acc': 0.5243, 'test_f1m': 0.4649, 'test_f1w': 0.5211, 'test_prec': None, 'test_rec': None, 'test_loss': 2.2082}
# GCN	 GCN_2L_split9.log	 test acc: 0.4893	 stats: {'train_acc': 0.7439, 'val_acc': 0.4924, 'test_acc': 0.4893, 'test_f1m': 0.423, 'test_f1w': 0.4843, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6492}
# SAGE	 SAGE_3L_split9.log	 test acc: 0.5192	 stats: {'train_acc': 0.9773, 'val_acc': 0.526, 'test_acc': 0.5192, 'test_f1m': 0.463, 'test_f1w': 0.5162, 'test_prec': None, 'test_rec': None, 'test_loss': 2.3717}
# GT	 GT-sep_4L_split9.log	 test acc: 0.5223	 stats: {'train_acc': 0.9441, 'val_acc': 0.5342, 'test_acc': 0.5223, 'test_f1m': 0.4666, 'test_f1w': 0.5194, 'test_prec': None, 'test_rec': None, 'test_loss': 2.137}
# ResNet	 ResNet_2L_split9.log	 test acc: 0.4637	 stats: {'train_acc': 0.8842, 'val_acc': 0.4627, 'test_acc': 0.4637, 'test_f1m': 0.3912, 'test_f1w': 0.4598, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0409}
#
# ====================================================================================================

# %%
tabm_files_path = 'results/amazon_ratings/logs_tabm'
tabm_files = os.listdir(tabm_files_path)

# %%
import re

for split in range(10):
    for model in ['GT-sep', 'GAT-sep', 'GAT', 'TAG', 'GCN', 'SAGE', 'GT', 'ResNet']:
        files = [
            x for x in tabm_files
            if model in x and f'split{split}' in x
        ]
        if len(files) == 0:
            continue
        scores = {}
        for file in files:
            with open(f'{tabm_files_path}/{file}', 'r') as f:
                content = f.read()
                train_match = re.search(r'train_acc=([\d.]+)', content)
                val_match = re.search(r'val_acc=([\d.]+)', content)
                test_acc_match = re.search(r'test_acc=([\d.]+)', content)
                test_f1m_match = re.search(r'test_f1m=([\d.]+)', content)
                test_f1w_match = re.search(r'test_f1w=([\d.]+)', content)
                test_prec_match = re.search(r'test_prec=([\d.]+)', content)
                test_rec_match = re.search(r'test_rec=([\d.]+)', content)
                test_loss_match = re.search(r'test_loss=([\d.]+)', content)
                scores[file] = {
                    'train_acc': float(train_match.group(1)) if train_match else None,
                    'val_acc': float(val_match.group(1)) if val_match else None,
                    'test_acc': float(test_acc_match.group(1)) if test_acc_match else None,
                    'test_f1m': float(test_f1m_match.group(1)) if test_f1m_match else None,
                    'test_f1w': float(test_f1w_match.group(1)) if test_f1w_match else None,
                    'test_prec': float(test_prec_match.group(1)) if test_prec_match else None,
                    'test_rec': float(test_rec_match.group(1)) if test_rec_match else None,
                    'test_loss': float(test_loss_match.group(1)) if test_loss_match else None
                }
        best_val_acc = 0
        for file, score in scores.items():
            if score['val_acc'] > best_val_acc:
                best_val_acc = score['val_acc']
                best_file = file
        print(f'{model}\t {best_file}\t test acc: {scores[best_file]["test_acc"]}\t stats: {scores[best_file]}')
        model2scores[model + '_TABM'].append(scores[best_file]["test_acc"])
    print()
    print('=' * 100)
    print()
# Out:
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================
#
#
# ====================================================================================================

# %%
ensemble_files_path = 'results/amazon_ratings/logs_ensemble'
ensemble_files = os.listdir(ensemble_files_path)

# %%
import re

for split in range(10):
    for model in ['GT-sep', 'GAT-sep', 'GAT', 'TAG', 'GCN', 'SAGE', 'GT', 'ResNet']:
        files = [
            x for x in ensemble_files
            if model in x and f'split{split}' in x
        ]
        if len(files) == 0:
            continue
        scores = {}
        for file in files:
            with open(f'{ensemble_files_path}/{file}', 'r') as f:
                content = f.read()
                train_match = re.search(r'train_acc=([\d.]+)', content)
                val_match = re.search(r'val_acc=([\d.]+)', content)
                test_acc_match = re.search(r'test_acc=([\d.]+)', content)
                test_f1m_match = re.search(r'test_f1m=([\d.]+)', content)
                test_f1w_match = re.search(r'test_f1w=([\d.]+)', content)
                test_prec_match = re.search(r'test_prec=([\d.]+)', content)
                test_rec_match = re.search(r'test_rec=([\d.]+)', content)
                test_loss_match = re.search(r'test_loss=([\d.]+)', content)
                scores[file] = {
                    'train_acc': float(train_match.group(1)) if train_match else None,
                    'val_acc': float(val_match.group(1)) if val_match else None,
                    'test_acc': float(test_acc_match.group(1)) if test_acc_match else None,
                    'test_f1m': float(test_f1m_match.group(1)) if test_f1m_match else None,
                    'test_f1w': float(test_f1w_match.group(1)) if test_f1w_match else None,
                    'test_prec': float(test_prec_match.group(1)) if test_prec_match else None,
                    'test_rec': float(test_rec_match.group(1)) if test_rec_match else None,
                    'test_loss': float(test_loss_match.group(1)) if test_loss_match else None
                }
        best_file = None
        best_val_acc = 0
        for file, score in scores.items():
            if score['val_acc'] or 0.0 > best_val_acc or 0.0:
                best_val_acc = score['val_acc']
                best_file = file
        if not best_file:
            continue
        print(f'{model}\t {best_file}\t test acc: {scores[best_file]["test_acc"]}\t stats: {scores[best_file]}')
        model2scores[model + '_ENS'].append(scores[best_file]["test_acc"])
    print()
    print('=' * 100)
    print()
# Out:
# GT-sep	 GT-sep_ens_split0.log	 test acc: 0.545	 stats: {'train_acc': 0.9614, 'val_acc': 0.5296, 'test_acc': 0.545, 'test_f1m': 0.4918, 'test_f1w': 0.5409, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8952}
# GAT-sep	 GAT-sep_ens_split0.log	 test acc: 0.5417	 stats: {'train_acc': 0.9526, 'val_acc': 0.5239, 'test_acc': 0.5417, 'test_f1m': 0.4914, 'test_f1w': 0.54, 'test_prec': None, 'test_rec': None, 'test_loss': 2.024}
# GAT	 GAT_ens_split0.log	 test acc: 0.4885	 stats: {'train_acc': 0.6677, 'val_acc': 0.4767, 'test_acc': 0.4885, 'test_f1m': 0.4138, 'test_f1w': 0.4801, 'test_prec': None, 'test_rec': None, 'test_loss': 1.4958}
# TAG	 TAG_ens_split0.log	 test acc: 0.5127	 stats: {'train_acc': 0.9212, 'val_acc': 0.4981, 'test_acc': 0.5127, 'test_f1m': 0.4636, 'test_f1w': 0.5108, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9959}
# GCN	 GCN_ens_split0.log	 test acc: 0.487	 stats: {'train_acc': 0.7072, 'val_acc': 0.4882, 'test_acc': 0.487, 'test_f1m': 0.4192, 'test_f1w': 0.4802, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5972}
# SAGE	 SAGE_ens_split0.log	 test acc: 0.5422	 stats: {'train_acc': 0.965, 'val_acc': 0.5187, 'test_acc': 0.5422, 'test_f1m': 0.4892, 'test_f1w': 0.537, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9409}
# GT	 GT_ens_split0.log	 test acc: 0.538	 stats: {'train_acc': 0.9304, 'val_acc': 0.5177, 'test_acc': 0.538, 'test_f1m': 0.4866, 'test_f1w': 0.5338, 'test_prec': None, 'test_rec': None, 'test_loss': 1.788}
# ResNet	 ResNet_ens_split0.log	 test acc: 0.4782	 stats: {'train_acc': 0.9017, 'val_acc': 0.4498, 'test_acc': 0.4782, 'test_f1m': 0.4266, 'test_f1w': 0.4745, 'test_prec': None, 'test_rec': None, 'test_loss': 1.7993}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split1.log	 test acc: 0.5409	 stats: {'train_acc': 0.965, 'val_acc': 0.5306, 'test_acc': 0.5409, 'test_f1m': 0.4906, 'test_f1w': 0.5373, 'test_prec': None, 'test_rec': None, 'test_loss': 1.923}
# GAT-sep	 GAT-sep_ens_split1.log	 test acc: 0.5391	 stats: {'train_acc': 0.9485, 'val_acc': 0.5357, 'test_acc': 0.5391, 'test_f1m': 0.4871, 'test_f1w': 0.536, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0218}
# GAT	 GAT-sep_ens_split1.log	 test acc: 0.5391	 stats: {'train_acc': 0.9485, 'val_acc': 0.5357, 'test_acc': 0.5391, 'test_f1m': 0.4871, 'test_f1w': 0.536, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0218}
# TAG	 TAG_ens_split1.log	 test acc: 0.5141	 stats: {'train_acc': 0.9063, 'val_acc': 0.5105, 'test_acc': 0.5141, 'test_f1m': 0.4664, 'test_f1w': 0.5115, 'test_prec': None, 'test_rec': None, 'test_loss': 1.7612}
# GCN	 GCN_ens_split1.log	 test acc: 0.4908	 stats: {'train_acc': 0.6379, 'val_acc': 0.4875, 'test_acc': 0.4908, 'test_f1m': 0.4126, 'test_f1w': 0.4822, 'test_prec': None, 'test_rec': None, 'test_loss': 1.3659}
# SAGE	 SAGE_ens_split1.log	 test acc: 0.5323	 stats: {'train_acc': 0.9656, 'val_acc': 0.5332, 'test_acc': 0.5323, 'test_f1m': 0.4836, 'test_f1w': 0.5283, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9762}
# GT	 GT_ens_split1.log	 test acc: 0.5419	 stats: {'train_acc': 0.9334, 'val_acc': 0.5336, 'test_acc': 0.5419, 'test_f1m': 0.4881, 'test_f1w': 0.5383, 'test_prec': None, 'test_rec': None, 'test_loss': 1.7934}
# ResNet	 ResNet_ens_split1.log	 test acc: 0.4743	 stats: {'train_acc': 0.8921, 'val_acc': 0.4555, 'test_acc': 0.4743, 'test_f1m': 0.4194, 'test_f1w': 0.4694, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8087}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split2.log	 test acc: 0.5401	 stats: {'train_acc': 0.9319, 'val_acc': 0.5251, 'test_acc': 0.5401, 'test_f1m': 0.4744, 'test_f1w': 0.536, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8044}
# GAT-sep	 GAT-sep_ens_split2.log	 test acc: 0.5324	 stats: {'train_acc': 0.9301, 'val_acc': 0.5223, 'test_acc': 0.5324, 'test_f1m': 0.4691, 'test_f1w': 0.5313, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0165}
# GAT	 GAT-sep_ens_split2.log	 test acc: 0.5324	 stats: {'train_acc': 0.9301, 'val_acc': 0.5223, 'test_acc': 0.5324, 'test_f1m': 0.4691, 'test_f1w': 0.5313, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0165}
# TAG	 TAG_ens_split2.log	 test acc: 0.5156	 stats: {'train_acc': 0.8331, 'val_acc': 0.51, 'test_acc': 0.5156, 'test_f1m': 0.4448, 'test_f1w': 0.5101, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6033}
# GCN	 GCN_ens_split2.log	 test acc: 0.4898	 stats: {'train_acc': 0.69, 'val_acc': 0.4795, 'test_acc': 0.4898, 'test_f1m': 0.4193, 'test_f1w': 0.4832, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5314}
# SAGE	 SAGE_ens_split2.log	 test acc: 0.5306	 stats: {'train_acc': 0.9665, 'val_acc': 0.5218, 'test_acc': 0.5306, 'test_f1m': 0.4675, 'test_f1w': 0.5267, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0233}
# GT	 GT-sep_ens_split2.log	 test acc: 0.5401	 stats: {'train_acc': 0.9319, 'val_acc': 0.5251, 'test_acc': 0.5401, 'test_f1m': 0.4744, 'test_f1w': 0.536, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8044}
# ResNet	 ResNet_ens_split2.log	 test acc: 0.4731	 stats: {'train_acc': 0.8929, 'val_acc': 0.462, 'test_acc': 0.4731, 'test_f1m': 0.4, 'test_f1w': 0.4662, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8675}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split3.log	 test acc: 0.5349	 stats: {'train_acc': 0.9538, 'val_acc': 0.5358, 'test_acc': 0.5349, 'test_f1m': 0.4775, 'test_f1w': 0.5314, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9275}
# GAT-sep	 GAT-sep_ens_split3.log	 test acc: 0.5316	 stats: {'train_acc': 0.9333, 'val_acc': 0.5373, 'test_acc': 0.5316, 'test_f1m': 0.4755, 'test_f1w': 0.5286, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9596}
# GAT	 GAT-sep_ens_split3.log	 test acc: 0.5316	 stats: {'train_acc': 0.9333, 'val_acc': 0.5373, 'test_acc': 0.5316, 'test_f1m': 0.4755, 'test_f1w': 0.5286, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9596}
# TAG	 TAG_ens_split3.log	 test acc: 0.5123	 stats: {'train_acc': 0.9152, 'val_acc': 0.5141, 'test_acc': 0.5123, 'test_f1m': 0.4611, 'test_f1w': 0.5107, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9742}
# GCN	 GCN_ens_split3.log	 test acc: 0.4798	 stats: {'train_acc': 0.705, 'val_acc': 0.4831, 'test_acc': 0.4798, 'test_f1m': 0.4207, 'test_f1w': 0.477, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6332}
# SAGE	 SAGE_ens_split3.log	 test acc: 0.5329	 stats: {'train_acc': 0.9631, 'val_acc': 0.5285, 'test_acc': 0.5329, 'test_f1m': 0.4773, 'test_f1w': 0.5281, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9558}
# GT	 GT_ens_split3.log	 test acc: 0.5363	 stats: {'train_acc': 0.9231, 'val_acc': 0.5275, 'test_acc': 0.5363, 'test_f1m': 0.4779, 'test_f1w': 0.533, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8321}
# ResNet	 ResNet_ens_split3.log	 test acc: 0.4749	 stats: {'train_acc': 0.8765, 'val_acc': 0.4695, 'test_acc': 0.4749, 'test_f1m': 0.4109, 'test_f1w': 0.4688, 'test_prec': None, 'test_rec': None, 'test_loss': 1.7949}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split4.log	 test acc: 0.5354	 stats: {'train_acc': 0.9577, 'val_acc': 0.5305, 'test_acc': 0.5354, 'test_f1m': 0.4713, 'test_f1w': 0.5319, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9237}
# GAT-sep	 GAT-sep_ens_split4.log	 test acc: 0.5443	 stats: {'train_acc': 0.9434, 'val_acc': 0.5432, 'test_acc': 0.5443, 'test_f1m': 0.4788, 'test_f1w': 0.542, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9981}
# GAT	 GAT_ens_split4.log	 test acc: 0.4852	 stats: {'train_acc': 0.6688, 'val_acc': 0.4821, 'test_acc': 0.4852, 'test_f1m': 0.4054, 'test_f1w': 0.4795, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5541}
# TAG	 TAG_ens_split4.log	 test acc: 0.5069	 stats: {'train_acc': 0.9175, 'val_acc': 0.5029, 'test_acc': 0.5069, 'test_f1m': 0.4449, 'test_f1w': 0.506, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0042}
# GCN	 GCN_ens_split4.log	 test acc: 0.4854	 stats: {'train_acc': 0.6707, 'val_acc': 0.4864, 'test_acc': 0.4854, 'test_f1m': 0.406, 'test_f1w': 0.4787, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5086}
# SAGE	 SAGE_ens_split4.log	 test acc: 0.5401	 stats: {'train_acc': 0.9624, 'val_acc': 0.5239, 'test_acc': 0.5401, 'test_f1m': 0.4659, 'test_f1w': 0.5344, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9489}
# GT	 GT-sep_ens_split4.log	 test acc: 0.5354	 stats: {'train_acc': 0.9577, 'val_acc': 0.5305, 'test_acc': 0.5354, 'test_f1m': 0.4713, 'test_f1w': 0.5319, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9237}
# ResNet	 ResNet_ens_split4.log	 test acc: 0.4759	 stats: {'train_acc': 0.9067, 'val_acc': 0.4591, 'test_acc': 0.4759, 'test_f1m': 0.4039, 'test_f1w': 0.4708, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8807}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split5.log	 test acc: 0.5443	 stats: {'train_acc': 0.9481, 'val_acc': 0.5254, 'test_acc': 0.5443, 'test_f1m': 0.4894, 'test_f1w': 0.5398, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9287}
# GAT-sep	 GAT-sep_ens_split5.log	 test acc: 0.5385	 stats: {'train_acc': 0.936, 'val_acc': 0.5229, 'test_acc': 0.5385, 'test_f1m': 0.4877, 'test_f1w': 0.5355, 'test_prec': None, 'test_rec': None, 'test_loss': 1.989}
# GAT	 GAT-sep_ens_split5.log	 test acc: 0.5385	 stats: {'train_acc': 0.936, 'val_acc': 0.5229, 'test_acc': 0.5385, 'test_f1m': 0.4877, 'test_f1w': 0.5355, 'test_prec': None, 'test_rec': None, 'test_loss': 1.989}
# TAG	 TAG_ens_split5.log	 test acc: 0.514	 stats: {'train_acc': 0.8983, 'val_acc': 0.513, 'test_acc': 0.514, 'test_f1m': 0.4585, 'test_f1w': 0.5117, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8966}
# GCN	 GCN_ens_split5.log	 test acc: 0.4872	 stats: {'train_acc': 0.7056, 'val_acc': 0.4901, 'test_acc': 0.4872, 'test_f1m': 0.4215, 'test_f1w': 0.4837, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6235}
# SAGE	 SAGE_ens_split5.log	 test acc: 0.5401	 stats: {'train_acc': 0.9746, 'val_acc': 0.5234, 'test_acc': 0.5401, 'test_f1m': 0.4875, 'test_f1w': 0.536, 'test_prec': None, 'test_rec': None, 'test_loss': 2.058}
# GT	 GT-sep_ens_split5.log	 test acc: 0.5443	 stats: {'train_acc': 0.9481, 'val_acc': 0.5254, 'test_acc': 0.5443, 'test_f1m': 0.4894, 'test_f1w': 0.5398, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9287}
# ResNet	 ResNet_ens_split5.log	 test acc: 0.4589	 stats: {'train_acc': 0.871, 'val_acc': 0.4519, 'test_acc': 0.4589, 'test_f1m': 0.3921, 'test_f1w': 0.4545, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8355}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split6.log	 test acc: 0.5399	 stats: {'train_acc': 0.9403, 'val_acc': 0.5403, 'test_acc': 0.5399, 'test_f1m': 0.4824, 'test_f1w': 0.5358, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8667}
# GAT-sep	 GAT-sep_ens_split6.log	 test acc: 0.5401	 stats: {'train_acc': 0.9343, 'val_acc': 0.5306, 'test_acc': 0.5401, 'test_f1m': 0.4836, 'test_f1w': 0.536, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9549}
# GAT	 GAT_ens_split6.log	 test acc: 0.4852	 stats: {'train_acc': 0.6795, 'val_acc': 0.479, 'test_acc': 0.4852, 'test_f1m': 0.4123, 'test_f1w': 0.4812, 'test_prec': None, 'test_rec': None, 'test_loss': 1.566}
# TAG	 TAG_ens_split6.log	 test acc: 0.5172	 stats: {'train_acc': 0.9051, 'val_acc': 0.5079, 'test_acc': 0.5172, 'test_f1m': 0.4622, 'test_f1w': 0.5155, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9738}
# GCN	 GCN_ens_split6.log	 test acc: 0.4873	 stats: {'train_acc': 0.7064, 'val_acc': 0.4836, 'test_acc': 0.4873, 'test_f1m': 0.4228, 'test_f1w': 0.4834, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5735}
# SAGE	 SAGE_ens_split6.log	 test acc: 0.5368	 stats: {'train_acc': 0.9417, 'val_acc': 0.5316, 'test_acc': 0.5368, 'test_f1m': 0.4778, 'test_f1w': 0.5304, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9011}
# GT	 GT_ens_split6.log	 test acc: 0.5406	 stats: {'train_acc': 0.9095, 'val_acc': 0.5336, 'test_acc': 0.5406, 'test_f1m': 0.4819, 'test_f1w': 0.5363, 'test_prec': None, 'test_rec': None, 'test_loss': 1.7794}
# ResNet	 ResNet_ens_split6.log	 test acc: 0.4717	 stats: {'train_acc': 0.8858, 'val_acc': 0.4593, 'test_acc': 0.4717, 'test_f1m': 0.4119, 'test_f1w': 0.4665, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8411}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split7.log	 test acc: 0.5368	 stats: {'train_acc': 0.9566, 'val_acc': 0.5221, 'test_acc': 0.5368, 'test_f1m': 0.4798, 'test_f1w': 0.5333, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9096}
# GAT-sep	 GAT-sep_ens_split7.log	 test acc: 0.5316	 stats: {'train_acc': 0.933, 'val_acc': 0.5293, 'test_acc': 0.5316, 'test_f1m': 0.476, 'test_f1w': 0.5291, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9542}
# GAT	 GAT-sep_ens_split7.log	 test acc: 0.5316	 stats: {'train_acc': 0.933, 'val_acc': 0.5293, 'test_acc': 0.5316, 'test_f1m': 0.476, 'test_f1w': 0.5291, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9542}
# TAG	 TAG_ens_split7.log	 test acc: 0.5061	 stats: {'train_acc': 0.9075, 'val_acc': 0.5071, 'test_acc': 0.5061, 'test_f1m': 0.4552, 'test_f1w': 0.5047, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9945}
# GCN	 GCN_ens_split7.log	 test acc: 0.4754	 stats: {'train_acc': 0.6766, 'val_acc': 0.4743, 'test_acc': 0.4754, 'test_f1m': 0.4075, 'test_f1w': 0.4706, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5086}
# SAGE	 SAGE_ens_split7.log	 test acc: 0.5285	 stats: {'train_acc': 0.9711, 'val_acc': 0.512, 'test_acc': 0.5285, 'test_f1m': 0.4667, 'test_f1w': 0.5244, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9841}
# GT	 GT_ens_split7.log	 test acc: 0.536	 stats: {'train_acc': 0.9349, 'val_acc': 0.5135, 'test_acc': 0.536, 'test_f1m': 0.4788, 'test_f1w': 0.5334, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8156}
# ResNet	 ResNet_ens_split7.log	 test acc: 0.4733	 stats: {'train_acc': 0.8741, 'val_acc': 0.4481, 'test_acc': 0.4733, 'test_f1m': 0.4082, 'test_f1w': 0.4665, 'test_prec': None, 'test_rec': None, 'test_loss': 1.7949}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split8.log	 test acc: 0.5373	 stats: {'train_acc': 0.9544, 'val_acc': 0.5329, 'test_acc': 0.5373, 'test_f1m': 0.4817, 'test_f1w': 0.5335, 'test_prec': None, 'test_rec': None, 'test_loss': 1.93}
# GAT-sep	 GAT-sep_ens_split8.log	 test acc: 0.5349	 stats: {'train_acc': 0.9397, 'val_acc': 0.5229, 'test_acc': 0.5349, 'test_f1m': 0.4741, 'test_f1w': 0.5322, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0555}
# GAT	 GAT-sep_ens_split8.log	 test acc: 0.5349	 stats: {'train_acc': 0.9397, 'val_acc': 0.5229, 'test_acc': 0.5349, 'test_f1m': 0.4741, 'test_f1w': 0.5322, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0555}
# TAG	 TAG_ens_split8.log	 test acc: None	 stats: {'train_acc': None, 'val_acc': 0.5042, 'test_acc': None, 'test_f1m': None, 'test_f1w': None, 'test_prec': None, 'test_rec': None, 'test_loss': None}
# GCN	 GCN_ens_split8.log	 test acc: 0.4833	 stats: {'train_acc': 0.6879, 'val_acc': 0.4877, 'test_acc': 0.4833, 'test_f1m': 0.4121, 'test_f1w': 0.4756, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5788}
# SAGE	 SAGE_ens_split8.log	 test acc: 0.5308	 stats: {'train_acc': 0.9643, 'val_acc': 0.5211, 'test_acc': 0.5308, 'test_f1m': 0.4712, 'test_f1w': 0.5252, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0529}
# GT	 GT_ens_split8.log	 test acc: 0.5376	 stats: {'train_acc': 0.92, 'val_acc': 0.5283, 'test_acc': 0.5376, 'test_f1m': 0.4731, 'test_f1w': 0.5337, 'test_prec': None, 'test_rec': None, 'test_loss': 1.8218}
# ResNet	 ResNet_ens_split8.log	 test acc: 0.4713	 stats: {'train_acc': 0.8709, 'val_acc': 0.4519, 'test_acc': 0.4713, 'test_f1m': 0.4045, 'test_f1w': 0.4632, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5933}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split9.log	 test acc: 0.5378	 stats: {'train_acc': 0.9529, 'val_acc': 0.5329, 'test_acc': 0.5378, 'test_f1m': 0.4836, 'test_f1w': 0.5342, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9583}
# GAT-sep	 GAT-sep_ens_split9.log	 test acc: 0.5314	 stats: {'train_acc': 0.9418, 'val_acc': 0.5154, 'test_acc': 0.5314, 'test_f1m': 0.4769, 'test_f1w': 0.5295, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0441}
# GAT	 GAT-sep_ens_split9.log	 test acc: 0.5314	 stats: {'train_acc': 0.9418, 'val_acc': 0.5154, 'test_acc': 0.5314, 'test_f1m': 0.4769, 'test_f1w': 0.5295, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0441}
# GCN	 GCN_ens_split9.log	 test acc: 0.4772	 stats: {'train_acc': 0.694, 'val_acc': 0.478, 'test_acc': 0.4772, 'test_f1m': 0.4091, 'test_f1w': 0.4736, 'test_prec': None, 'test_rec': None, 'test_loss': 1.6238}
# SAGE	 SAGE_ens_split9.log	 test acc: 0.5419	 stats: {'train_acc': 0.975, 'val_acc': 0.5184, 'test_acc': 0.5419, 'test_f1m': 0.4854, 'test_f1w': 0.5381, 'test_prec': None, 'test_rec': None, 'test_loss': 2.0621}
# GT	 GT-sep_ens_split9.log	 test acc: 0.5378	 stats: {'train_acc': 0.9529, 'val_acc': 0.5329, 'test_acc': 0.5378, 'test_f1m': 0.4836, 'test_f1w': 0.5342, 'test_prec': None, 'test_rec': None, 'test_loss': 1.9583}
# ResNet	 ResNet_ens_split9.log	 test acc: 0.4772	 stats: {'train_acc': 0.885, 'val_acc': 0.4419, 'test_acc': 0.4772, 'test_f1m': 0.4034, 'test_f1w': 0.4699, 'test_prec': None, 'test_rec': None, 'test_loss': 1.5671}
#
# ====================================================================================================

# %%
keys = sorted(list(model2scores.keys()))

# %%
import numpy as np

for key in keys:
    values = model2scores[key]
    print(f"{key}: \t{np.mean(values)*100:.3f} +- {np.std(values)*100:.3f}")
    if 'TABM' in key:
        print()
# Out:
# GAT-sep_BASE: 	54.021 +- 0.389
# GAT-sep_ENS: 	53.656 +- 0.453
# GAT_BASE: 	54.021 +- 0.389
# GAT_ENS: 	52.318 +- 2.099
# GCN_BASE: 	48.792 +- 0.457
# GCN_ENS: 	48.477 +- 0.480
# GT-sep_BASE: 	52.636 +- 0.593
# GT-sep_ENS: 	53.924 +- 0.329
# GT_BASE: 	52.685 +- 0.542
# GT_ENS: 	53.918 +- 0.297
# ResNet_BASE: 	46.492 +- 0.473
# ResNet_ENS: 	47.260 +- 0.516
# SAGE_BASE: 	52.748 +- 0.628
# SAGE_ENS: 	53.522 +- 0.480
# TAG_BASE: 	51.581 +- 0.576
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       3 for key in keys:
#       4     values = model2scores[key]
# ----> 5     print(f"{key}: \t{np.mean(values)*100:.3f} +- {np.std(values)*100:.3f}")
#       6     if 'TABM' in key:
#       7         print()
#
# File ~/other_datasets/venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860, in mean(a, axis, dtype, out, keepdims, where)
#    3857     else:
#    3858         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3860 return _methods._mean(a, axis=axis, dtype=dtype,
#    3861                       out=out, **kwargs)
#
# File ~/other_datasets/venv/lib/python3.10/site-packages/numpy/_core/_methods.py:135, in _mean(a, axis, dtype, out, keepdims, where)
#     132         dtype = mu.dtype('f4')
#     133         is_float16_result = True
# --> 135 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     136 if isinstance(ret, mu.ndarray):
#     137     ret = um.true_divide(
#     138             ret, rcount, out=ret, casting='unsafe', subok=False)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'
