# %%
import pandas as pd
import os

base_files_path = 'roman_empire/logs_base'
base_files = os.listdir(base_files_path)

# %%
list(set([x.split('_')[0] for x in base_files]))
# Out:
# ['SAGE', 'ResNet', 'GCN', 'GT', 'GAT', 'GT-sep', 'TAG', 'GAT-sep']

# %%
from collections import defaultdict
model2scores = defaultdict(list)

# %%
import re

for split in range(10):
    for model in ['GT-sep', 'GAT-sep', 'GAT', 'TAG', 'GCN', 'SAGE', 'GT', 'ResNet']:
        files = [
            x for x in base_files
            if f'{model}_' in x and f'split{split}' in x
            and '_5L_' in x
        ]
        if len(files) == 0:
            continue
        scores = {}
        for file in files:
            with open(f'{base_files_path}/{file}', 'r') as f:
                content = f.read()
                train_match = re.search(r'train_acc=([\d.]+)', content)
                val_match = re.search(r'val_acc=([\d.]+)', content)
                test_acc_match = re.search(r'test_acc=([\d.]+)', content)
                test_f1m_match = re.search(r'test_f1m=([\d.]+)', content)
                test_f1w_match = re.search(r'test_f1w=([\d.]+)', content)
                test_prec_match = re.search(r'test_prec=([\d.]+)', content)
                test_rec_match = re.search(r'test_rec=([\d.]+)', content)
                test_loss_match = re.search(r'test_loss=([\d.]+)', content)
                scores[file] = {
                    'train_acc': float(train_match.group(1)) if train_match else None,
                    'val_acc': float(val_match.group(1)) if val_match else None,
                    'test_acc': float(test_acc_match.group(1)) if test_acc_match else None,
                    'test_f1m': float(test_f1m_match.group(1)) if test_f1m_match else None,
                    'test_f1w': float(test_f1w_match.group(1)) if test_f1w_match else None,
                    'test_prec': float(test_prec_match.group(1)) if test_prec_match else None,
                    'test_rec': float(test_rec_match.group(1)) if test_rec_match else None,
                    'test_loss': float(test_loss_match.group(1)) if test_loss_match else None
                }
        best_val_acc = 0
        for file, score in scores.items():
            if score['val_acc'] > best_val_acc:
                best_val_acc = score['val_acc']
                best_file = file
        print(f'{model}\t {best_file}\t test acc: {scores[best_file]["test_acc"]}\t stats: {scores[best_file]}')
        model2scores[model + "_BASE"].append(scores[best_file]["test_acc"])
    print()
    print('=' * 100)
    print()
# Out:
# GT-sep	 GT-sep_5L_split0.log	 test acc: 0.8623	 stats: {'train_acc': 0.9998, 'val_acc': 0.8685, 'test_acc': 0.8623, 'test_f1m': 0.8277, 'test_f1w': 0.8608, 'test_prec': 0.827, 'test_rec': 0.8296, 'test_loss': 0.7223}
# GAT-sep	 GAT-sep_5L_split0.log	 test acc: 0.8775	 stats: {'train_acc': 0.9998, 'val_acc': 0.8851, 'test_acc': 0.8775, 'test_f1m': 0.8435, 'test_f1w': 0.8764, 'test_prec': 0.8386, 'test_rec': 0.853, 'test_loss': 0.6361}
# GAT	 GAT_5L_split0.log	 test acc: 0.7905	 stats: {'train_acc': 0.9775, 'val_acc': 0.7981, 'test_acc': 0.7905, 'test_f1m': 0.737, 'test_f1w': 0.7897, 'test_prec': 0.725, 'test_rec': 0.7578, 'test_loss': 0.7782}
# TAG	 TAG_5L_split0.log	 test acc: 0.8572	 stats: {'train_acc': 0.9999, 'val_acc': 0.8648, 'test_acc': 0.8572, 'test_f1m': 0.8219, 'test_f1w': 0.8561, 'test_prec': 0.8192, 'test_rec': 0.826, 'test_loss': 0.7781}
# GCN	 GCN_5L_split0.log	 test acc: 0.6991	 stats: {'train_acc': 0.9282, 'val_acc': 0.719, 'test_acc': 0.6991, 'test_f1m': 0.6277, 'test_f1w': 0.7001, 'test_prec': 0.6238, 'test_rec': 0.6387, 'test_loss': 0.9888}
# SAGE	 SAGE_5L_split0.log	 test acc: 0.8466	 stats: {'train_acc': 0.9995, 'val_acc': 0.853, 'test_acc': 0.8466, 'test_f1m': 0.8048, 'test_f1w': 0.8457, 'test_prec': 0.7995, 'test_rec': 0.8122, 'test_loss': 0.8516}
# GT	 GT_5L_split0.log	 test acc: 0.8662	 stats: {'train_acc': 0.9998, 'val_acc': 0.8738, 'test_acc': 0.8662, 'test_f1m': 0.8318, 'test_f1w': 0.8645, 'test_prec': 0.8283, 'test_rec': 0.8374, 'test_loss': 0.6649}
# ResNet	 ResNet_5L_split0.log	 test acc: 0.6555	 stats: {'train_acc': 0.7187, 'val_acc': 0.6515, 'test_acc': 0.6555, 'test_f1m': 0.536, 'test_f1w': 0.6329, 'test_prec': 0.5262, 'test_rec': 0.5743, 'test_loss': 1.0937}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split1.log	 test acc: 0.8745	 stats: {'train_acc': 1.0, 'val_acc': 0.88, 'test_acc': 0.8745, 'test_f1m': 0.8466, 'test_f1w': 0.8726, 'test_prec': 0.8536, 'test_rec': 0.8431, 'test_loss': 0.6286}
# GAT-sep	 GAT-sep_5L_split1.log	 test acc: 0.8892	 stats: {'train_acc': 0.9999, 'val_acc': 0.8906, 'test_acc': 0.8892, 'test_f1m': 0.8624, 'test_f1w': 0.8891, 'test_prec': 0.8612, 'test_rec': 0.8654, 'test_loss': 0.5412}
# GAT	 GAT_5L_split1.log	 test acc: 0.8099	 stats: {'train_acc': 0.9791, 'val_acc': 0.8164, 'test_acc': 0.8099, 'test_f1m': 0.7593, 'test_f1w': 0.8078, 'test_prec': 0.7607, 'test_rec': 0.7633, 'test_loss': 0.6759}
# TAG	 TAG_5L_split1.log	 test acc: 0.8713	 stats: {'train_acc': 0.9999, 'val_acc': 0.8676, 'test_acc': 0.8713, 'test_f1m': 0.8386, 'test_f1w': 0.8708, 'test_prec': 0.8368, 'test_rec': 0.8413, 'test_loss': 0.7049}
# GCN	 GCN_5L_split1.log	 test acc: 0.7199	 stats: {'train_acc': 0.9426, 'val_acc': 0.7246, 'test_acc': 0.7199, 'test_f1m': 0.6497, 'test_f1w': 0.7183, 'test_prec': 0.6476, 'test_rec': 0.6562, 'test_loss': 0.9288}
# SAGE	 SAGE_5L_split1.log	 test acc: 0.8577	 stats: {'train_acc': 0.9996, 'val_acc': 0.8613, 'test_acc': 0.8577, 'test_f1m': 0.8208, 'test_f1w': 0.8558, 'test_prec': 0.824, 'test_rec': 0.82, 'test_loss': 0.8016}
# GT	 GT_5L_split1.log	 test acc: 0.8802	 stats: {'train_acc': 0.9999, 'val_acc': 0.8849, 'test_acc': 0.8802, 'test_f1m': 0.8514, 'test_f1w': 0.8792, 'test_prec': 0.8552, 'test_rec': 0.8486, 'test_loss': 0.6182}
# ResNet	 ResNet_5L_split1.log	 test acc: 0.6641	 stats: {'train_acc': 0.7104, 'val_acc': 0.6614, 'test_acc': 0.6641, 'test_f1m': 0.5391, 'test_f1w': 0.6374, 'test_prec': 0.5469, 'test_rec': 0.558, 'test_loss': 1.0668}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split2.log	 test acc: 0.868	 stats: {'train_acc': 0.9998, 'val_acc': 0.8643, 'test_acc': 0.868, 'test_f1m': 0.8359, 'test_f1w': 0.8663, 'test_prec': 0.8375, 'test_rec': 0.8361, 'test_loss': 0.6704}
# GAT-sep	 GAT-sep_5L_split2.log	 test acc: 0.883	 stats: {'train_acc': 1.0, 'val_acc': 0.878, 'test_acc': 0.883, 'test_f1m': 0.8548, 'test_f1w': 0.8821, 'test_prec': 0.8532, 'test_rec': 0.8602, 'test_loss': 0.5893}
# GAT	 GAT_5L_split2.log	 test acc: 0.7993	 stats: {'train_acc': 0.9824, 'val_acc': 0.7986, 'test_acc': 0.7993, 'test_f1m': 0.7508, 'test_f1w': 0.7986, 'test_prec': 0.7463, 'test_rec': 0.7624, 'test_loss': 0.7112}
# TAG	 TAG_5L_split2.log	 test acc: 0.8602	 stats: {'train_acc': 0.9998, 'val_acc': 0.8625, 'test_acc': 0.8602, 'test_f1m': 0.823, 'test_f1w': 0.8595, 'test_prec': 0.8229, 'test_rec': 0.8247, 'test_loss': 0.751}
# GCN	 GCN_5L_split2.log	 test acc: 0.7098	 stats: {'train_acc': 0.991, 'val_acc': 0.7158, 'test_acc': 0.7098, 'test_f1m': 0.6465, 'test_f1w': 0.7098, 'test_prec': 0.6439, 'test_rec': 0.6539, 'test_loss': 1.1707}
# SAGE	 SAGE_5L_split2.log	 test acc: 0.8574	 stats: {'train_acc': 0.9997, 'val_acc': 0.8501, 'test_acc': 0.8574, 'test_f1m': 0.8238, 'test_f1w': 0.856, 'test_prec': 0.8238, 'test_rec': 0.8252, 'test_loss': 0.7678}
# GT	 GT_5L_split2.log	 test acc: 0.872	 stats: {'train_acc': 0.9997, 'val_acc': 0.8704, 'test_acc': 0.872, 'test_f1m': 0.8412, 'test_f1w': 0.87, 'test_prec': 0.8424, 'test_rec': 0.8424, 'test_loss': 0.6174}
# ResNet	 ResNet_5L_split2.log	 test acc: 0.6583	 stats: {'train_acc': 0.6994, 'val_acc': 0.6542, 'test_acc': 0.6583, 'test_f1m': 0.5312, 'test_f1w': 0.6331, 'test_prec': 0.5466, 'test_rec': 0.5487, 'test_loss': 1.0845}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split3.log	 test acc: 0.8655	 stats: {'train_acc': 0.9996, 'val_acc': 0.8711, 'test_acc': 0.8655, 'test_f1m': 0.8329, 'test_f1w': 0.8643, 'test_prec': 0.833, 'test_rec': 0.8344, 'test_loss': 0.6787}
# GAT-sep	 GAT-sep_5L_split3.log	 test acc: 0.889	 stats: {'train_acc': 0.9996, 'val_acc': 0.8925, 'test_acc': 0.889, 'test_f1m': 0.8652, 'test_f1w': 0.8888, 'test_prec': 0.8614, 'test_rec': 0.8718, 'test_loss': 0.5617}
# GAT	 GAT_5L_split3.log	 test acc: 0.8103	 stats: {'train_acc': 0.9794, 'val_acc': 0.8173, 'test_acc': 0.8103, 'test_f1m': 0.7611, 'test_f1w': 0.8089, 'test_prec': 0.7574, 'test_rec': 0.7698, 'test_loss': 0.6834}
# TAG	 TAG_5L_split3.log	 test acc: 0.8636	 stats: {'train_acc': 0.9998, 'val_acc': 0.8694, 'test_acc': 0.8636, 'test_f1m': 0.8361, 'test_f1w': 0.8614, 'test_prec': 0.8377, 'test_rec': 0.8371, 'test_loss': 0.7366}
# GCN	 GCN_5L_split3.log	 test acc: 0.7192	 stats: {'train_acc': 0.912, 'val_acc': 0.7266, 'test_acc': 0.7192, 'test_f1m': 0.6567, 'test_f1w': 0.7191, 'test_prec': 0.6602, 'test_rec': 0.6585, 'test_loss': 0.9149}
# SAGE	 SAGE_5L_split3.log	 test acc: 0.8505	 stats: {'train_acc': 0.9989, 'val_acc': 0.8544, 'test_acc': 0.8505, 'test_f1m': 0.8119, 'test_f1w': 0.8482, 'test_prec': 0.8107, 'test_rec': 0.8144, 'test_loss': 0.8077}
# GT	 GT_5L_split3.log	 test acc: 0.8798	 stats: {'train_acc': 0.9998, 'val_acc': 0.8856, 'test_acc': 0.8798, 'test_f1m': 0.8496, 'test_f1w': 0.8783, 'test_prec': 0.85, 'test_rec': 0.8507, 'test_loss': 0.6254}
# ResNet	 ResNet_5L_split3.log	 test acc: 0.6613	 stats: {'train_acc': 0.7224, 'val_acc': 0.6554, 'test_acc': 0.6613, 'test_f1m': 0.5426, 'test_f1w': 0.6377, 'test_prec': 0.6029, 'test_rec': 0.5605, 'test_loss': 1.0786}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split4.log	 test acc: 0.8657	 stats: {'train_acc': 0.9998, 'val_acc': 0.8697, 'test_acc': 0.8657, 'test_f1m': 0.8333, 'test_f1w': 0.8638, 'test_prec': 0.8263, 'test_rec': 0.843, 'test_loss': 0.7076}
# GAT-sep	 GAT-sep_5L_split4.log	 test acc: 0.8856	 stats: {'train_acc': 0.9999, 'val_acc': 0.8854, 'test_acc': 0.8856, 'test_f1m': 0.8587, 'test_f1w': 0.8844, 'test_prec': 0.8478, 'test_rec': 0.8735, 'test_loss': 0.6069}
# GAT	 GAT_5L_split4.log	 test acc: 0.7992	 stats: {'train_acc': 0.9772, 'val_acc': 0.8092, 'test_acc': 0.7992, 'test_f1m': 0.7427, 'test_f1w': 0.7983, 'test_prec': 0.7344, 'test_rec': 0.7598, 'test_loss': 0.7372}
# TAG	 TAG_5L_split4.log	 test acc: 0.8632	 stats: {'train_acc': 0.9999, 'val_acc': 0.8731, 'test_acc': 0.8632, 'test_f1m': 0.8343, 'test_f1w': 0.8606, 'test_prec': 0.8313, 'test_rec': 0.8411, 'test_loss': 0.7931}
# GCN	 GCN_5L_split4.log	 test acc: 0.7081	 stats: {'train_acc': 0.9349, 'val_acc': 0.7252, 'test_acc': 0.7081, 'test_f1m': 0.6407, 'test_f1w': 0.7108, 'test_prec': 0.6385, 'test_rec': 0.6511, 'test_loss': 0.9588}
# SAGE	 SAGE_5L_split4.log	 test acc: 0.844	 stats: {'train_acc': 0.9995, 'val_acc': 0.8535, 'test_acc': 0.844, 'test_f1m': 0.8054, 'test_f1w': 0.8416, 'test_prec': 0.7972, 'test_rec': 0.8184, 'test_loss': 0.8298}
# GT	 GT_5L_split4.log	 test acc: 0.8735	 stats: {'train_acc': 0.9998, 'val_acc': 0.8733, 'test_acc': 0.8735, 'test_f1m': 0.8414, 'test_f1w': 0.8712, 'test_prec': 0.8359, 'test_rec': 0.8495, 'test_loss': 0.6098}
# ResNet	 ResNet_5L_split4.log	 test acc: 0.6567	 stats: {'train_acc': 0.7181, 'val_acc': 0.6597, 'test_acc': 0.6567, 'test_f1m': 0.5396, 'test_f1w': 0.634, 'test_prec': 0.5633, 'test_rec': 0.5543, 'test_loss': 1.1024}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split5.log	 test acc: 0.8773	 stats: {'train_acc': 0.9996, 'val_acc': 0.869, 'test_acc': 0.8773, 'test_f1m': 0.8401, 'test_f1w': 0.8754, 'test_prec': 0.8483, 'test_rec': 0.8353, 'test_loss': 0.6254}
# GAT-sep	 GAT-sep_5L_split5.log	 test acc: 0.8909	 stats: {'train_acc': 0.9996, 'val_acc': 0.8858, 'test_acc': 0.8909, 'test_f1m': 0.8595, 'test_f1w': 0.8903, 'test_prec': 0.8596, 'test_rec': 0.8616, 'test_loss': 0.5416}
# GAT	 GAT_5L_split5.log	 test acc: 0.8023	 stats: {'train_acc': 0.982, 'val_acc': 0.8007, 'test_acc': 0.8023, 'test_f1m': 0.7411, 'test_f1w': 0.7998, 'test_prec': 0.7449, 'test_rec': 0.7466, 'test_loss': 0.6923}
# TAG	 TAG_5L_split5.log	 test acc: 0.8738	 stats: {'train_acc': 1.0, 'val_acc': 0.8643, 'test_acc': 0.8738, 'test_f1m': 0.8391, 'test_f1w': 0.8727, 'test_prec': 0.8404, 'test_rec': 0.8394, 'test_loss': 0.6595}
# GCN	 GCN_5L_split5.log	 test acc: 0.7136	 stats: {'train_acc': 0.9891, 'val_acc': 0.7241, 'test_acc': 0.7136, 'test_f1m': 0.6459, 'test_f1w': 0.7135, 'test_prec': 0.6483, 'test_rec': 0.6501, 'test_loss': 1.0898}
# SAGE	 SAGE_5L_split5.log	 test acc: 0.8652	 stats: {'train_acc': 0.999, 'val_acc': 0.8537, 'test_acc': 0.8652, 'test_f1m': 0.8271, 'test_f1w': 0.8633, 'test_prec': 0.8319, 'test_rec': 0.8249, 'test_loss': 0.7439}
# GT	 GT_5L_split5.log	 test acc: 0.884	 stats: {'train_acc': 0.9995, 'val_acc': 0.8747, 'test_acc': 0.884, 'test_f1m': 0.8508, 'test_f1w': 0.8831, 'test_prec': 0.8534, 'test_rec': 0.8502, 'test_loss': 0.5623}
# ResNet	 ResNet_5L_split5.log	 test acc: 0.6647	 stats: {'train_acc': 0.6993, 'val_acc': 0.6593, 'test_acc': 0.6647, 'test_f1m': 0.5363, 'test_f1w': 0.6345, 'test_prec': 0.5566, 'test_rec': 0.5534, 'test_loss': 1.0394}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split6.log	 test acc: 0.8664	 stats: {'train_acc': 0.9997, 'val_acc': 0.8597, 'test_acc': 0.8664, 'test_f1m': 0.8371, 'test_f1w': 0.8653, 'test_prec': 0.8412, 'test_rec': 0.8346, 'test_loss': 0.7155}
# GAT-sep	 GAT-sep_5L_split6.log	 test acc: 0.8867	 stats: {'train_acc': 0.9998, 'val_acc': 0.8789, 'test_acc': 0.8867, 'test_f1m': 0.8604, 'test_f1w': 0.8857, 'test_prec': 0.8598, 'test_rec': 0.8659, 'test_loss': 0.5862}
# GAT	 GAT_5L_split6.log	 test acc: 0.8143	 stats: {'train_acc': 0.9831, 'val_acc': 0.8034, 'test_acc': 0.8143, 'test_f1m': 0.7646, 'test_f1w': 0.8129, 'test_prec': 0.7596, 'test_rec': 0.7758, 'test_loss': 0.6688}
# TAG	 TAG_5L_split6.log	 test acc: 0.865	 stats: {'train_acc': 1.0, 'val_acc': 0.865, 'test_acc': 0.865, 'test_f1m': 0.8301, 'test_f1w': 0.8636, 'test_prec': 0.8247, 'test_rec': 0.837, 'test_loss': 0.6955}
# GCN	 GCN_5L_split6.log	 test acc: 0.7173	 stats: {'train_acc': 0.918, 'val_acc': 0.7204, 'test_acc': 0.7173, 'test_f1m': 0.6616, 'test_f1w': 0.7169, 'test_prec': 0.6581, 'test_rec': 0.6714, 'test_loss': 0.8948}
# SAGE	 SAGE_5L_split6.log	 test acc: 0.853	 stats: {'train_acc': 0.9996, 'val_acc': 0.8464, 'test_acc': 0.853, 'test_f1m': 0.8117, 'test_f1w': 0.852, 'test_prec': 0.8094, 'test_rec': 0.8169, 'test_loss': 0.815}
# GT	 GT_5L_split6.log	 test acc: 0.8729	 stats: {'train_acc': 0.9997, 'val_acc': 0.8745, 'test_acc': 0.8729, 'test_f1m': 0.8413, 'test_f1w': 0.8714, 'test_prec': 0.8436, 'test_rec': 0.841, 'test_loss': 0.636}
# ResNet	 ResNet_5L_split6.log	 test acc: 0.6551	 stats: {'train_acc': 0.7186, 'val_acc': 0.6554, 'test_acc': 0.6551, 'test_f1m': 0.5307, 'test_f1w': 0.6311, 'test_prec': 0.5426, 'test_rec': 0.5506, 'test_loss': 1.1005}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split7.log	 test acc: 0.8586	 stats: {'train_acc': 0.9997, 'val_acc': 0.8664, 'test_acc': 0.8586, 'test_f1m': 0.826, 'test_f1w': 0.857, 'test_prec': 0.828, 'test_rec': 0.8262, 'test_loss': 0.7643}
# GAT-sep	 GAT-sep_5L_split7.log	 test acc: 0.877	 stats: {'train_acc': 0.9996, 'val_acc': 0.8817, 'test_acc': 0.877, 'test_f1m': 0.8491, 'test_f1w': 0.8762, 'test_prec': 0.8471, 'test_rec': 0.8569, 'test_loss': 0.6401}
# GAT	 GAT_5L_split7.log	 test acc: 0.8018	 stats: {'train_acc': 0.9864, 'val_acc': 0.8026, 'test_acc': 0.8018, 'test_f1m': 0.7489, 'test_f1w': 0.7998, 'test_prec': 0.7473, 'test_rec': 0.7589, 'test_loss': 0.7538}
# TAG	 TAG_5L_split7.log	 test acc: 0.8606	 stats: {'train_acc': 0.9998, 'val_acc': 0.8581, 'test_acc': 0.8606, 'test_f1m': 0.8275, 'test_f1w': 0.8598, 'test_prec': 0.8293, 'test_rec': 0.8277, 'test_loss': 0.7908}
# GCN	 GCN_5L_split7.log	 test acc: 0.7158	 stats: {'train_acc': 0.9872, 'val_acc': 0.7227, 'test_acc': 0.7158, 'test_f1m': 0.6575, 'test_f1w': 0.7177, 'test_prec': 0.66, 'test_rec': 0.6602, 'test_loss': 1.102}
# SAGE	 SAGE_5L_split7.log	 test acc: 0.8509	 stats: {'train_acc': 0.9995, 'val_acc': 0.8549, 'test_acc': 0.8509, 'test_f1m': 0.8073, 'test_f1w': 0.8492, 'test_prec': 0.8044, 'test_rec': 0.8124, 'test_loss': 0.8428}
# GT	 GT_5L_split7.log	 test acc: 0.8669	 stats: {'train_acc': 0.9997, 'val_acc': 0.8695, 'test_acc': 0.8669, 'test_f1m': 0.8341, 'test_f1w': 0.8654, 'test_prec': 0.8311, 'test_rec': 0.8401, 'test_loss': 0.7034}
# ResNet	 ResNet_5L_split7.log	 test acc: 0.6601	 stats: {'train_acc': 0.7051, 'val_acc': 0.6507, 'test_acc': 0.6601, 'test_f1m': 0.5222, 'test_f1w': 0.6271, 'test_prec': 0.5448, 'test_rec': 0.5411, 'test_loss': 1.0958}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split8.log	 test acc: 0.8611	 stats: {'train_acc': 0.9996, 'val_acc': 0.8685, 'test_acc': 0.8611, 'test_f1m': 0.8274, 'test_f1w': 0.8599, 'test_prec': 0.8265, 'test_rec': 0.83, 'test_loss': 0.6644}
# GAT-sep	 GAT-sep_5L_split8.log	 test acc: 0.8761	 stats: {'train_acc': 0.9998, 'val_acc': 0.8838, 'test_acc': 0.8761, 'test_f1m': 0.8447, 'test_f1w': 0.8761, 'test_prec': 0.844, 'test_rec': 0.849, 'test_loss': 0.636}
# GAT	 GAT_5L_split8.log	 test acc: 0.8044	 stats: {'train_acc': 0.9861, 'val_acc': 0.8, 'test_acc': 0.8044, 'test_f1m': 0.7504, 'test_f1w': 0.8033, 'test_prec': 0.7507, 'test_rec': 0.7593, 'test_loss': 0.7486}
# TAG	 TAG_5L_split8.log	 test acc: 0.8576	 stats: {'train_acc': 0.9999, 'val_acc': 0.8611, 'test_acc': 0.8576, 'test_f1m': 0.8234, 'test_f1w': 0.8561, 'test_prec': 0.8216, 'test_rec': 0.8284, 'test_loss': 0.7949}
# GCN	 GCN_5L_split8.log	 test acc: 0.701	 stats: {'train_acc': 0.9923, 'val_acc': 0.7158, 'test_acc': 0.701, 'test_f1m': 0.642, 'test_f1w': 0.7039, 'test_prec': 0.6453, 'test_rec': 0.6449, 'test_loss': 1.2016}
# SAGE	 SAGE_5L_split8.log	 test acc: 0.8521	 stats: {'train_acc': 0.9994, 'val_acc': 0.8547, 'test_acc': 0.8521, 'test_f1m': 0.8106, 'test_f1w': 0.8505, 'test_prec': 0.8121, 'test_rec': 0.8117, 'test_loss': 0.8449}
# GT	 GT_5L_split8.log	 test acc: 0.871	 stats: {'train_acc': 0.9999, 'val_acc': 0.8778, 'test_acc': 0.871, 'test_f1m': 0.8389, 'test_f1w': 0.8699, 'test_prec': 0.8377, 'test_rec': 0.8416, 'test_loss': 0.6652}
# ResNet	 ResNet_5L_split8.log	 test acc: 0.6652	 stats: {'train_acc': 0.719, 'val_acc': 0.6523, 'test_acc': 0.6652, 'test_f1m': 0.5401, 'test_f1w': 0.6423, 'test_prec': 0.5431, 'test_rec': 0.5649, 'test_loss': 1.093}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_5L_split9.log	 test acc: 0.8639	 stats: {'train_acc': 0.9996, 'val_acc': 0.868, 'test_acc': 0.8639, 'test_f1m': 0.8328, 'test_f1w': 0.8615, 'test_prec': 0.8333, 'test_rec': 0.8343, 'test_loss': 0.7141}
# GAT-sep	 GAT-sep_5L_split9.log	 test acc: 0.8818	 stats: {'train_acc': 0.9996, 'val_acc': 0.8856, 'test_acc': 0.8818, 'test_f1m': 0.8549, 'test_f1w': 0.881, 'test_prec': 0.8448, 'test_rec': 0.8691, 'test_loss': 0.5922}
# GAT	 GAT_5L_split9.log	 test acc: 0.8066	 stats: {'train_acc': 0.9808, 'val_acc': 0.815, 'test_acc': 0.8066, 'test_f1m': 0.7533, 'test_f1w': 0.8047, 'test_prec': 0.7433, 'test_rec': 0.7706, 'test_loss': 0.7089}
# TAG	 TAG_5L_split9.log	 test acc: 0.8678	 stats: {'train_acc': 0.9999, 'val_acc': 0.8674, 'test_acc': 0.8678, 'test_f1m': 0.8352, 'test_f1w': 0.8667, 'test_prec': 0.8298, 'test_rec': 0.8421, 'test_loss': 0.7333}
# GCN	 GCN_5L_split9.log	 test acc: 0.7068	 stats: {'train_acc': 0.9895, 'val_acc': 0.7209, 'test_acc': 0.7068, 'test_f1m': 0.6461, 'test_f1w': 0.709, 'test_prec': 0.6427, 'test_rec': 0.655, 'test_loss': 1.18}
# SAGE	 SAGE_5L_split9.log	 test acc: 0.8484	 stats: {'train_acc': 0.9994, 'val_acc': 0.8553, 'test_acc': 0.8484, 'test_f1m': 0.8063, 'test_f1w': 0.8458, 'test_prec': 0.8018, 'test_rec': 0.8142, 'test_loss': 0.8392}
# GT	 GT_5L_split9.log	 test acc: 0.8729	 stats: {'train_acc': 0.9996, 'val_acc': 0.878, 'test_acc': 0.8729, 'test_f1m': 0.8446, 'test_f1w': 0.871, 'test_prec': 0.8459, 'test_rec': 0.8451, 'test_loss': 0.6317}
# ResNet	 ResNet_5L_split9.log	 test acc: 0.6516	 stats: {'train_acc': 0.7147, 'val_acc': 0.6568, 'test_acc': 0.6516, 'test_f1m': 0.5212, 'test_f1w': 0.6193, 'test_prec': 0.5411, 'test_rec': 0.5456, 'test_loss': 1.1148}
#
# ====================================================================================================

# %%
tabm_files_path = 'roman_empire/logs_tabm'
tabm_files = os.listdir(tabm_files_path)

# %%
import re

for split in range(10):
    for model in ['GT-sep', 'GAT-sep', 'GAT', 'TAG', 'GCN', 'SAGE', 'GT', 'ResNet']:
        files = [
            x for x in tabm_files
            if f'{model}_' in x and f'split{split}' in x
        ]
        if len(files) == 0:
            continue
        scores = {}
        for file in files:
            with open(f'{tabm_files_path}/{file}', 'r') as f:
                content = f.read()
                train_match = re.search(r'train_acc=([\d.]+)', content)
                val_match = re.search(r'val_acc=([\d.]+)', content)
                test_acc_match = re.search(r'test_acc=([\d.]+)', content)
                test_f1m_match = re.search(r'test_f1m=([\d.]+)', content)
                test_f1w_match = re.search(r'test_f1w=([\d.]+)', content)
                test_prec_match = re.search(r'test_prec=([\d.]+)', content)
                test_rec_match = re.search(r'test_rec=([\d.]+)', content)
                test_loss_match = re.search(r'test_loss=([\d.]+)', content)
                scores[file] = {
                    'train_acc': float(train_match.group(1)) if train_match else None,
                    'val_acc': float(val_match.group(1)) if val_match else None,
                    'test_acc': float(test_acc_match.group(1)) if test_acc_match else None,
                    'test_f1m': float(test_f1m_match.group(1)) if test_f1m_match else None,
                    'test_f1w': float(test_f1w_match.group(1)) if test_f1w_match else None,
                    'test_prec': float(test_prec_match.group(1)) if test_prec_match else None,
                    'test_rec': float(test_rec_match.group(1)) if test_rec_match else None,
                    'test_loss': float(test_loss_match.group(1)) if test_loss_match else None
                }
        best_val_acc = 0
        for file, score in scores.items():
            if score['val_acc'] > best_val_acc:
                best_val_acc = score['val_acc']
                best_file = file
        print(f'{model}\t {best_file}\t test acc: {scores[best_file]["test_acc"]}\t stats: {scores[best_file]}')
        model2scores[model + '_TABM'].append(scores[best_file]["test_acc"])
    print()
    print('=' * 100)
    print()
# Out:
# GT-sep	 TABM-GT-sep_5L_split0.log	 test acc: 0.8816	 stats: {'train_acc': 0.9984, 'val_acc': 0.8874, 'test_acc': 0.8816, 'test_f1m': 0.8476, 'test_f1w': 0.8792, 'test_prec': 0.8441, 'test_rec': 0.8539, 'test_loss': 0.4972}
# GAT-sep	 TABM-GAT-sep_5L_split0.log	 test acc: 0.8897	 stats: {'train_acc': 0.9914, 'val_acc': 0.8959, 'test_acc': 0.8897, 'test_f1m': 0.8597, 'test_f1w': 0.8885, 'test_prec': 0.8527, 'test_rec': 0.872, 'test_loss': 0.4641}
# GAT	 TABM-GAT_5L_split0.log	 test acc: 0.782	 stats: {'train_acc': 0.9014, 'val_acc': 0.7864, 'test_acc': 0.782, 'test_f1m': 0.7183, 'test_f1w': 0.7799, 'test_prec': 0.7199, 'test_rec': 0.7415, 'test_loss': 0.7362}
# TAG	 TABM-TAG_5L_split0.log	 test acc: 0.8697	 stats: {'train_acc': 0.9985, 'val_acc': 0.8761, 'test_acc': 0.8697, 'test_f1m': 0.8366, 'test_f1w': 0.8691, 'test_prec': 0.8348, 'test_rec': 0.8397, 'test_loss': 0.5524}
# GCN	 TABM-GCN_5L_split0.log	 test acc: 0.7453	 stats: {'train_acc': 0.9605, 'val_acc': 0.7497, 'test_acc': 0.7453, 'test_f1m': 0.6851, 'test_f1w': 0.7456, 'test_prec': 0.6864, 'test_rec': 0.6926, 'test_loss': 0.8741}
# SAGE	 TABM-SAGE_5L_split0.log	 test acc: 0.8703	 stats: {'train_acc': 0.9921, 'val_acc': 0.8759, 'test_acc': 0.8703, 'test_f1m': 0.8349, 'test_f1w': 0.8691, 'test_prec': 0.827, 'test_rec': 0.846, 'test_loss': 0.5538}
# GT	 TABM-GT_5L_split0.log	 test acc: 0.8869	 stats: {'train_acc': 0.9921, 'val_acc': 0.8881, 'test_acc': 0.8869, 'test_f1m': 0.8568, 'test_f1w': 0.8848, 'test_prec': 0.8511, 'test_rec': 0.8664, 'test_loss': 0.4608}
# ResNet	 TABM-ResNet_5L_split0.log	 test acc: 0.6528	 stats: {'train_acc': 0.7034, 'val_acc': 0.6575, 'test_acc': 0.6528, 'test_f1m': 0.5196, 'test_f1w': 0.6199, 'test_prec': 0.5222, 'test_rec': 0.5629, 'test_loss': 1.076}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split1.log	 test acc: 0.8816	 stats: {'train_acc': 0.9968, 'val_acc': 0.8891, 'test_acc': 0.8816, 'test_f1m': 0.8511, 'test_f1w': 0.8795, 'test_prec': 0.8528, 'test_rec': 0.8523, 'test_loss': 0.4789}
# GAT-sep	 TABM-GAT-sep_5L_split1.log	 test acc: 0.8946	 stats: {'train_acc': 0.9903, 'val_acc': 0.8948, 'test_acc': 0.8946, 'test_f1m': 0.8677, 'test_f1w': 0.894, 'test_prec': 0.8633, 'test_rec': 0.8742, 'test_loss': 0.4201}
# GAT	 TABM-GAT_5L_split1.log	 test acc: 0.7932	 stats: {'train_acc': 0.9088, 'val_acc': 0.7901, 'test_acc': 0.7932, 'test_f1m': 0.733, 'test_f1w': 0.7901, 'test_prec': 0.7427, 'test_rec': 0.7416, 'test_loss': 0.704}
# TAG	 TABM-TAG_5L_split1.log	 test acc: 0.8803	 stats: {'train_acc': 0.9991, 'val_acc': 0.8775, 'test_acc': 0.8803, 'test_f1m': 0.8501, 'test_f1w': 0.8792, 'test_prec': 0.8485, 'test_rec': 0.8534, 'test_loss': 0.5371}
# GCN	 TABM-GCN_5L_split1.log	 test acc: 0.7621	 stats: {'train_acc': 0.9699, 'val_acc': 0.7605, 'test_acc': 0.7621, 'test_f1m': 0.7007, 'test_f1w': 0.7584, 'test_prec': 0.7103, 'test_rec': 0.6983, 'test_loss': 0.8437}
# SAGE	 TABM-SAGE_5L_split1.log	 test acc: 0.8791	 stats: {'train_acc': 0.9905, 'val_acc': 0.8805, 'test_acc': 0.8791, 'test_f1m': 0.8468, 'test_f1w': 0.8776, 'test_prec': 0.8447, 'test_rec': 0.8504, 'test_loss': 0.5135}
# GT	 TABM-GT_5L_split1.log	 test acc: 0.8862	 stats: {'train_acc': 0.9957, 'val_acc': 0.8904, 'test_acc': 0.8862, 'test_f1m': 0.8552, 'test_f1w': 0.8839, 'test_prec': 0.8582, 'test_rec': 0.8555, 'test_loss': 0.448}
# ResNet	 TABM-ResNet_5L_split1.log	 test acc: 0.6585	 stats: {'train_acc': 0.7053, 'val_acc': 0.6567, 'test_acc': 0.6585, 'test_f1m': 0.5391, 'test_f1w': 0.6297, 'test_prec': 0.54, 'test_rec': 0.5748, 'test_loss': 1.0664}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split2.log	 test acc: 0.8899	 stats: {'train_acc': 0.9981, 'val_acc': 0.8833, 'test_acc': 0.8899, 'test_f1m': 0.8614, 'test_f1w': 0.888, 'test_prec': 0.8628, 'test_rec': 0.8632, 'test_loss': 0.4635}
# GAT-sep	 TABM-GAT-sep_5L_split2.log	 test acc: 0.895	 stats: {'train_acc': 0.9908, 'val_acc': 0.8853, 'test_acc': 0.895, 'test_f1m': 0.8692, 'test_f1w': 0.8943, 'test_prec': 0.8621, 'test_rec': 0.8804, 'test_loss': 0.4109}
# GAT	 TABM-GAT_5L_split2.log	 test acc: 0.7965	 stats: {'train_acc': 0.9223, 'val_acc': 0.7876, 'test_acc': 0.7965, 'test_f1m': 0.7441, 'test_f1w': 0.7928, 'test_prec': 0.7527, 'test_rec': 0.752, 'test_loss': 0.6516}
# TAG	 TABM-TAG_5L_split2.log	 test acc: 0.8758	 stats: {'train_acc': 0.9986, 'val_acc': 0.8699, 'test_acc': 0.8758, 'test_f1m': 0.8477, 'test_f1w': 0.8753, 'test_prec': 0.845, 'test_rec': 0.8516, 'test_loss': 0.5217}
# GCN	 TABM-GCN_5L_split2.log	 test acc: 0.7566	 stats: {'train_acc': 0.97, 'val_acc': 0.7589, 'test_acc': 0.7566, 'test_f1m': 0.7008, 'test_f1w': 0.7553, 'test_prec': 0.6995, 'test_rec': 0.7075, 'test_loss': 0.8406}
# SAGE	 TABM-SAGE_5L_split2.log	 test acc: 0.8717	 stats: {'train_acc': 0.9886, 'val_acc': 0.8713, 'test_acc': 0.8717, 'test_f1m': 0.8403, 'test_f1w': 0.8701, 'test_prec': 0.8358, 'test_rec': 0.8471, 'test_loss': 0.5143}
# GT	 TABM-GT_5L_split2.log	 test acc: 0.8856	 stats: {'train_acc': 0.9943, 'val_acc': 0.8846, 'test_acc': 0.8856, 'test_f1m': 0.8568, 'test_f1w': 0.8837, 'test_prec': 0.8553, 'test_rec': 0.8619, 'test_loss': 0.4377}
# ResNet	 TABM-ResNet_5L_split2.log	 test acc: 0.6595	 stats: {'train_acc': 0.7193, 'val_acc': 0.6575, 'test_acc': 0.6595, 'test_f1m': 0.5424, 'test_f1w': 0.6333, 'test_prec': 0.5545, 'test_rec': 0.573, 'test_loss': 1.0797}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split3.log	 test acc: 0.8848	 stats: {'train_acc': 0.9988, 'val_acc': 0.8904, 'test_acc': 0.8848, 'test_f1m': 0.8548, 'test_f1w': 0.8826, 'test_prec': 0.8547, 'test_rec': 0.8577, 'test_loss': 0.5067}
# GAT-sep	 TABM-GAT-sep_5L_split3.log	 test acc: 0.8881	 stats: {'train_acc': 0.9913, 'val_acc': 0.896, 'test_acc': 0.8881, 'test_f1m': 0.8596, 'test_f1w': 0.8884, 'test_prec': 0.8516, 'test_rec': 0.8706, 'test_loss': 0.4529}
# GAT	 TABM-GAT_5L_split3.log	 test acc: 0.7917	 stats: {'train_acc': 0.9158, 'val_acc': 0.7961, 'test_acc': 0.7917, 'test_f1m': 0.7426, 'test_f1w': 0.7921, 'test_prec': 0.7417, 'test_rec': 0.758, 'test_loss': 0.6986}
# TAG	 TABM-TAG_5L_split3.log	 test acc: 0.8731	 stats: {'train_acc': 0.9994, 'val_acc': 0.88, 'test_acc': 0.8731, 'test_f1m': 0.8431, 'test_f1w': 0.8722, 'test_prec': 0.8423, 'test_rec': 0.8451, 'test_loss': 0.5809}
# GCN	 TABM-GCN_5L_split3.log	 test acc: 0.7619	 stats: {'train_acc': 0.9654, 'val_acc': 0.7575, 'test_acc': 0.7619, 'test_f1m': 0.7153, 'test_f1w': 0.7627, 'test_prec': 0.7183, 'test_rec': 0.7177, 'test_loss': 0.8434}
# SAGE	 TABM-SAGE_5L_split3.log	 test acc: 0.8765	 stats: {'train_acc': 0.9909, 'val_acc': 0.8791, 'test_acc': 0.8765, 'test_f1m': 0.8476, 'test_f1w': 0.8755, 'test_prec': 0.841, 'test_rec': 0.8557, 'test_loss': 0.5404}
# GT	 TABM-GT_5L_split3.log	 test acc: 0.8888	 stats: {'train_acc': 0.9976, 'val_acc': 0.89, 'test_acc': 0.8888, 'test_f1m': 0.8612, 'test_f1w': 0.8868, 'test_prec': 0.8589, 'test_rec': 0.8662, 'test_loss': 0.4688}
# ResNet	 TABM-ResNet_5L_split3.log	 test acc: 0.6638	 stats: {'train_acc': 0.7123, 'val_acc': 0.657, 'test_acc': 0.6638, 'test_f1m': 0.5337, 'test_f1w': 0.6351, 'test_prec': 0.5422, 'test_rec': 0.5647, 'test_loss': 1.061}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split4.log	 test acc: 0.8772	 stats: {'train_acc': 0.993, 'val_acc': 0.8824, 'test_acc': 0.8772, 'test_f1m': 0.8476, 'test_f1w': 0.874, 'test_prec': 0.8428, 'test_rec': 0.8564, 'test_loss': 0.5036}
# GAT-sep	 TABM-GAT-sep_5L_split4.log	 test acc: 0.8867	 stats: {'train_acc': 0.9907, 'val_acc': 0.8974, 'test_acc': 0.8867, 'test_f1m': 0.8588, 'test_f1w': 0.8853, 'test_prec': 0.8524, 'test_rec': 0.8688, 'test_loss': 0.4431}
# GAT	 TABM-GAT_5L_split4.log	 test acc: 0.7859	 stats: {'train_acc': 0.9103, 'val_acc': 0.8009, 'test_acc': 0.7859, 'test_f1m': 0.7226, 'test_f1w': 0.782, 'test_prec': 0.7224, 'test_rec': 0.7438, 'test_loss': 0.7187}
# TAG	 TABM-TAG_5L_split4.log	 test acc: 0.8705	 stats: {'train_acc': 0.9971, 'val_acc': 0.8784, 'test_acc': 0.8705, 'test_f1m': 0.8412, 'test_f1w': 0.8684, 'test_prec': 0.8363, 'test_rec': 0.849, 'test_loss': 0.5789}
# GCN	 TABM-GCN_5L_split4.log	 test acc: 0.7556	 stats: {'train_acc': 0.9591, 'val_acc': 0.7663, 'test_acc': 0.7556, 'test_f1m': 0.6893, 'test_f1w': 0.752, 'test_prec': 0.6881, 'test_rec': 0.6994, 'test_loss': 0.8355}
# SAGE	 TABM-SAGE_5L_split4.log	 test acc: 0.8727	 stats: {'train_acc': 0.9884, 'val_acc': 0.8793, 'test_acc': 0.8727, 'test_f1m': 0.8429, 'test_f1w': 0.8703, 'test_prec': 0.8356, 'test_rec': 0.8528, 'test_loss': 0.5528}
# GT	 TABM-GT_5L_split4.log	 test acc: 0.8872	 stats: {'train_acc': 0.9921, 'val_acc': 0.8918, 'test_acc': 0.8872, 'test_f1m': 0.858, 'test_f1w': 0.8849, 'test_prec': 0.8527, 'test_rec': 0.8679, 'test_loss': 0.4512}
# ResNet	 TABM-ResNet_5L_split4.log	 test acc: 0.6537	 stats: {'train_acc': 0.7184, 'val_acc': 0.6575, 'test_acc': 0.6537, 'test_f1m': 0.5364, 'test_f1w': 0.6277, 'test_prec': 0.5424, 'test_rec': 0.5699, 'test_loss': 1.1074}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split5.log	 test acc: 0.883	 stats: {'train_acc': 0.9969, 'val_acc': 0.8828, 'test_acc': 0.883, 'test_f1m': 0.8477, 'test_f1w': 0.8808, 'test_prec': 0.8471, 'test_rec': 0.8508, 'test_loss': 0.4786}
# GAT-sep	 TABM-GAT-sep_5L_split5.log	 test acc: 0.9015	 stats: {'train_acc': 0.9929, 'val_acc': 0.8959, 'test_acc': 0.9015, 'test_f1m': 0.8748, 'test_f1w': 0.9009, 'test_prec': 0.8714, 'test_rec': 0.8807, 'test_loss': 0.398}
# GAT	 TABM-GAT_5L_split5.log	 test acc: 0.7937	 stats: {'train_acc': 0.9117, 'val_acc': 0.7898, 'test_acc': 0.7937, 'test_f1m': 0.7262, 'test_f1w': 0.7881, 'test_prec': 0.7457, 'test_rec': 0.7331, 'test_loss': 0.6707}
# TAG	 TABM-TAG_5L_split5.log	 test acc: 0.8874	 stats: {'train_acc': 0.9991, 'val_acc': 0.878, 'test_acc': 0.8874, 'test_f1m': 0.8572, 'test_f1w': 0.8871, 'test_prec': 0.8564, 'test_rec': 0.859, 'test_loss': 0.4907}
# GCN	 TABM-GCN_5L_split5.log	 test acc: 0.7607	 stats: {'train_acc': 0.9604, 'val_acc': 0.7608, 'test_acc': 0.7607, 'test_f1m': 0.7077, 'test_f1w': 0.7618, 'test_prec': 0.7164, 'test_rec': 0.7095, 'test_loss': 0.8084}
# SAGE	 TABM-SAGE_5L_split5.log	 test acc: 0.8863	 stats: {'train_acc': 0.9926, 'val_acc': 0.8754, 'test_acc': 0.8863, 'test_f1m': 0.8555, 'test_f1w': 0.8851, 'test_prec': 0.8544, 'test_rec': 0.8581, 'test_loss': 0.5022}
# GT	 TABM-GT_5L_split5.log	 test acc: 0.8881	 stats: {'train_acc': 0.9953, 'val_acc': 0.8883, 'test_acc': 0.8881, 'test_f1m': 0.8591, 'test_f1w': 0.8866, 'test_prec': 0.8569, 'test_rec': 0.8638, 'test_loss': 0.4331}
# ResNet	 TABM-ResNet_5L_split5.log	 test acc: 0.668	 stats: {'train_acc': 0.7002, 'val_acc': 0.6651, 'test_acc': 0.668, 'test_f1m': 0.5393, 'test_f1w': 0.6346, 'test_prec': 0.5552, 'test_rec': 0.5808, 'test_loss': 1.0433}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split6.log	 test acc: 0.8743	 stats: {'train_acc': 0.9976, 'val_acc': 0.8803, 'test_acc': 0.8743, 'test_f1m': 0.842, 'test_f1w': 0.8722, 'test_prec': 0.8417, 'test_rec': 0.846, 'test_loss': 0.5289}
# GAT-sep	 TABM-GAT-sep_5L_split6.log	 test acc: 0.887	 stats: {'train_acc': 0.9926, 'val_acc': 0.8876, 'test_acc': 0.887, 'test_f1m': 0.8618, 'test_f1w': 0.8859, 'test_prec': 0.8574, 'test_rec': 0.8704, 'test_loss': 0.4636}
# GAT	 TABM-GAT_5L_split6.log	 test acc: 0.7928	 stats: {'train_acc': 0.9253, 'val_acc': 0.7864, 'test_acc': 0.7928, 'test_f1m': 0.7339, 'test_f1w': 0.7906, 'test_prec': 0.7375, 'test_rec': 0.7478, 'test_loss': 0.6924}
# TAG	 TABM-TAG_5L_split6.log	 test acc: 0.871	 stats: {'train_acc': 0.9981, 'val_acc': 0.8687, 'test_acc': 0.871, 'test_f1m': 0.8419, 'test_f1w': 0.8702, 'test_prec': 0.8392, 'test_rec': 0.8459, 'test_loss': 0.564}
# GCN	 TABM-GCN_5L_split6.log	 test acc: 0.7511	 stats: {'train_acc': 0.9622, 'val_acc': 0.7502, 'test_acc': 0.7511, 'test_f1m': 0.6956, 'test_f1w': 0.7513, 'test_prec': 0.7008, 'test_rec': 0.6959, 'test_loss': 0.8459}
# SAGE	 TABM-SAGE_5L_split6.log	 test acc: 0.8722	 stats: {'train_acc': 0.9912, 'val_acc': 0.8641, 'test_acc': 0.8722, 'test_f1m': 0.84, 'test_f1w': 0.8707, 'test_prec': 0.8352, 'test_rec': 0.8483, 'test_loss': 0.5719}
# GT	 TABM-GT_5L_split6.log	 test acc: 0.8803	 stats: {'train_acc': 0.9962, 'val_acc': 0.8823, 'test_acc': 0.8803, 'test_f1m': 0.8535, 'test_f1w': 0.8784, 'test_prec': 0.8516, 'test_rec': 0.8588, 'test_loss': 0.4761}
# ResNet	 TABM-ResNet_5L_split6.log	 test acc: 0.6528	 stats: {'train_acc': 0.7089, 'val_acc': 0.6597, 'test_acc': 0.6528, 'test_f1m': 0.5282, 'test_f1w': 0.6203, 'test_prec': 0.5585, 'test_rec': 0.5667, 'test_loss': 1.0896}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split7.log	 test acc: 0.8913	 stats: {'train_acc': 0.997, 'val_acc': 0.8791, 'test_acc': 0.8913, 'test_f1m': 0.8629, 'test_f1w': 0.8893, 'test_prec': 0.8675, 'test_rec': 0.8611, 'test_loss': 0.4934}
# GAT-sep	 TABM-GAT-sep_5L_split7.log	 test acc: 0.892	 stats: {'train_acc': 0.9935, 'val_acc': 0.892, 'test_acc': 0.892, 'test_f1m': 0.8642, 'test_f1w': 0.8912, 'test_prec': 0.858, 'test_rec': 0.8747, 'test_loss': 0.4639}
# GAT	 TABM-GAT_5L_split7.log	 test acc: 0.7983	 stats: {'train_acc': 0.907, 'val_acc': 0.7954, 'test_acc': 0.7983, 'test_f1m': 0.7409, 'test_f1w': 0.7955, 'test_prec': 0.7445, 'test_rec': 0.7627, 'test_loss': 0.681}
# TAG	 TABM-TAG_5L_split7.log	 test acc: 0.8758	 stats: {'train_acc': 0.9981, 'val_acc': 0.8724, 'test_acc': 0.8758, 'test_f1m': 0.8429, 'test_f1w': 0.875, 'test_prec': 0.8364, 'test_rec': 0.8509, 'test_loss': 0.5713}
# GCN	 TABM-GCN_5L_split7.log	 test acc: 0.7686	 stats: {'train_acc': 0.9675, 'val_acc': 0.7628, 'test_acc': 0.7686, 'test_f1m': 0.7119, 'test_f1w': 0.7682, 'test_prec': 0.7098, 'test_rec': 0.7186, 'test_loss': 0.8092}
# SAGE	 TABM-SAGE_5L_split7.log	 test acc: 0.8727	 stats: {'train_acc': 0.9905, 'val_acc': 0.8727, 'test_acc': 0.8727, 'test_f1m': 0.8396, 'test_f1w': 0.8713, 'test_prec': 0.8352, 'test_rec': 0.8469, 'test_loss': 0.5574}
# GT	 TABM-GT_5L_split7.log	 test acc: 0.8867	 stats: {'train_acc': 0.9944, 'val_acc': 0.8833, 'test_acc': 0.8867, 'test_f1m': 0.8582, 'test_f1w': 0.8855, 'test_prec': 0.8567, 'test_rec': 0.8622, 'test_loss': 0.4656}
# ResNet	 TABM-ResNet_5L_split7.log	 test acc: 0.664	 stats: {'train_acc': 0.7201, 'val_acc': 0.6549, 'test_acc': 0.664, 'test_f1m': 0.5388, 'test_f1w': 0.6338, 'test_prec': 0.544, 'test_rec': 0.5766, 'test_loss': 1.0894}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split8.log	 test acc: 0.8895	 stats: {'train_acc': 0.9946, 'val_acc': 0.8812, 'test_acc': 0.8895, 'test_f1m': 0.8629, 'test_f1w': 0.8882, 'test_prec': 0.8609, 'test_rec': 0.8669, 'test_loss': 0.4587}
# GAT-sep	 TABM-GAT-sep_5L_split8.log	 test acc: 0.8883	 stats: {'train_acc': 0.9907, 'val_acc': 0.8946, 'test_acc': 0.8883, 'test_f1m': 0.8628, 'test_f1w': 0.888, 'test_prec': 0.8565, 'test_rec': 0.8725, 'test_loss': 0.429}
# GAT	 TABM-GAT_5L_split8.log	 test acc: 0.7909	 stats: {'train_acc': 0.9193, 'val_acc': 0.7972, 'test_acc': 0.7909, 'test_f1m': 0.7334, 'test_f1w': 0.789, 'test_prec': 0.74, 'test_rec': 0.7432, 'test_loss': 0.7112}
# TAG	 TABM-TAG_5L_split8.log	 test acc: 0.8727	 stats: {'train_acc': 0.9979, 'val_acc': 0.8704, 'test_acc': 0.8727, 'test_f1m': 0.842, 'test_f1w': 0.8726, 'test_prec': 0.8357, 'test_rec': 0.8501, 'test_loss': 0.5664}
# GCN	 TABM-GCN_5L_split8.log	 test acc: 0.7489	 stats: {'train_acc': 0.9658, 'val_acc': 0.7529, 'test_acc': 0.7489, 'test_f1m': 0.6972, 'test_f1w': 0.7489, 'test_prec': 0.6976, 'test_rec': 0.7063, 'test_loss': 0.8596}
# SAGE	 TABM-SAGE_5L_split8.log	 test acc: 0.8675	 stats: {'train_acc': 0.9855, 'val_acc': 0.8724, 'test_acc': 0.8675, 'test_f1m': 0.8335, 'test_f1w': 0.8661, 'test_prec': 0.8276, 'test_rec': 0.842, 'test_loss': 0.5477}
# GT	 TABM-GT_5L_split8.log	 test acc: 0.8878	 stats: {'train_acc': 0.9919, 'val_acc': 0.8853, 'test_acc': 0.8878, 'test_f1m': 0.8603, 'test_f1w': 0.8864, 'test_prec': 0.8575, 'test_rec': 0.8652, 'test_loss': 0.4366}
# ResNet	 TABM-ResNet_5L_split8.log	 test acc: 0.6603	 stats: {'train_acc': 0.7164, 'val_acc': 0.6563, 'test_acc': 0.6603, 'test_f1m': 0.5359, 'test_f1w': 0.6327, 'test_prec': 0.5328, 'test_rec': 0.5785, 'test_loss': 1.0753}
#
# ====================================================================================================
#
# GT-sep	 TABM-GT-sep_5L_split9.log	 test acc: 0.8828	 stats: {'train_acc': 0.9961, 'val_acc': 0.8853, 'test_acc': 0.8828, 'test_f1m': 0.8528, 'test_f1w': 0.8803, 'test_prec': 0.851, 'test_rec': 0.8582, 'test_loss': 0.4674}
# GAT-sep	 TABM-GAT-sep_5L_split9.log	 test acc: 0.8902	 stats: {'train_acc': 0.9905, 'val_acc': 0.8957, 'test_acc': 0.8902, 'test_f1m': 0.862, 'test_f1w': 0.889, 'test_prec': 0.8557, 'test_rec': 0.8715, 'test_loss': 0.4266}
# GAT	 TABM-GAT_5L_split9.log	 test acc: 0.788	 stats: {'train_acc': 0.9084, 'val_acc': 0.7894, 'test_acc': 0.788, 'test_f1m': 0.7258, 'test_f1w': 0.7837, 'test_prec': 0.7307, 'test_rec': 0.7425, 'test_loss': 0.7071}
# TAG	 TABM-TAG_5L_split9.log	 test acc: 0.8729	 stats: {'train_acc': 0.9976, 'val_acc': 0.8708, 'test_acc': 0.8729, 'test_f1m': 0.8367, 'test_f1w': 0.8723, 'test_prec': 0.8309, 'test_rec': 0.8459, 'test_loss': 0.5263}
# GCN	 TABM-GCN_5L_split9.log	 test acc: 0.7575	 stats: {'train_acc': 0.965, 'val_acc': 0.7603, 'test_acc': 0.7575, 'test_f1m': 0.6992, 'test_f1w': 0.7558, 'test_prec': 0.7061, 'test_rec': 0.7004, 'test_loss': 0.8295}
# SAGE	 TABM-SAGE_5L_split9.log	 test acc: 0.8754	 stats: {'train_acc': 0.989, 'val_acc': 0.8736, 'test_acc': 0.8754, 'test_f1m': 0.8411, 'test_f1w': 0.8741, 'test_prec': 0.8327, 'test_rec': 0.8525, 'test_loss': 0.5348}
# GT	 TABM-GT_5L_split9.log	 test acc: 0.8881	 stats: {'train_acc': 0.9956, 'val_acc': 0.8913, 'test_acc': 0.8881, 'test_f1m': 0.8596, 'test_f1w': 0.886, 'test_prec': 0.8534, 'test_rec': 0.869, 'test_loss': 0.4384}
# ResNet	 TABM-ResNet_5L_split9.log	 test acc: 0.6576	 stats: {'train_acc': 0.7045, 'val_acc': 0.6625, 'test_acc': 0.6576, 'test_f1m': 0.5246, 'test_f1w': 0.6216, 'test_prec': 0.5477, 'test_rec': 0.5635, 'test_loss': 1.0957}
#
# ====================================================================================================

# %%
ensemble_files_path = 'logs_ensemble'
ensemble_files = os.listdir(ensemble_files_path)

# %%
import re

for split in range(10):
    for model in ['GT-sep', 'GAT-sep', 'GAT', 'TAG', 'GCN', 'SAGE', 'GT', 'ResNet']:
        files = [
            x for x in ensemble_files
            if f'{model}_' in x and f'split{split}' in x
        ]
        if len(files) == 0:
            continue
        scores = {}
        for file in files:
            with open(f'{ensemble_files_path}/{file}', 'r') as f:
                content = f.read()
                train_match = re.search(r'train_acc=([\d.]+)', content)
                val_match = re.search(r'val_acc=([\d.]+)', content)
                test_acc_match = re.search(r'test_acc=([\d.]+)', content)
                test_f1m_match = re.search(r'test_f1m=([\d.]+)', content)
                test_f1w_match = re.search(r'test_f1w=([\d.]+)', content)
                test_prec_match = re.search(r'test_prec=([\d.]+)', content)
                test_rec_match = re.search(r'test_rec=([\d.]+)', content)
                test_loss_match = re.search(r'test_loss=([\d.]+)', content)
                scores[file] = {
                    'train_acc': float(train_match.group(1)) if train_match else None,
                    'val_acc': float(val_match.group(1)) if val_match else None,
                    'test_acc': float(test_acc_match.group(1)) if test_acc_match else None,
                    'test_f1m': float(test_f1m_match.group(1)) if test_f1m_match else None,
                    'test_f1w': float(test_f1w_match.group(1)) if test_f1w_match else None,
                    'test_prec': float(test_prec_match.group(1)) if test_prec_match else None,
                    'test_rec': float(test_rec_match.group(1)) if test_rec_match else None,
                    'test_loss': float(test_loss_match.group(1)) if test_loss_match else None
                }
        best_file = None
        best_val_acc = 0
        for file, score in scores.items():
            if score['val_acc'] or 0.0 > best_val_acc or 0.0:
                best_val_acc = score['val_acc']
                best_file = file
        if not best_file:
            continue
        print(f'{model}\t {best_file}\t test acc: {scores[best_file]["test_acc"]}\t stats: {scores[best_file]}')
        model2scores[model + '_ENS'].append(scores[best_file]["test_acc"])
    print()
    print('=' * 100)
    print()
# Out:
# GT-sep	 GT-sep_ens_split0.log	 test acc: 0.8694	 stats: {'train_acc': 0.9999, 'val_acc': 0.8685, 'test_acc': 0.8694, 'test_f1m': 0.8359, 'test_f1w': 0.8675, 'test_prec': 0.8323, 'test_rec': 0.8413, 'test_loss': 0.6557}
# GAT-sep	 GAT-sep_ens_split0.log	 test acc: 0.8846	 stats: {'train_acc': 0.9998, 'val_acc': 0.8849, 'test_acc': 0.8846, 'test_f1m': 0.8531, 'test_f1w': 0.8834, 'test_prec': 0.8461, 'test_rec': 0.8645, 'test_loss': 0.5721}
# GAT	 GAT_ens_split0.log	 test acc: 0.8067	 stats: {'train_acc': 0.9876, 'val_acc': 0.7982, 'test_acc': 0.8067, 'test_f1m': 0.7514, 'test_f1w': 0.8043, 'test_prec': 0.7453, 'test_rec': 0.765, 'test_loss': 0.6776}
# TAG	 TAG_ens_split0.log	 test acc: 0.8648	 stats: {'train_acc': 0.9999, 'val_acc': 0.8648, 'test_acc': 0.8648, 'test_f1m': 0.8305, 'test_f1w': 0.8635, 'test_prec': 0.8267, 'test_rec': 0.8354, 'test_loss': 0.6916}
# GCN	 GCN_ens_split0.log	 test acc: 0.7227	 stats: {'train_acc': 0.9814, 'val_acc': 0.719, 'test_acc': 0.7227, 'test_f1m': 0.657, 'test_f1w': 0.7233, 'test_prec': 0.655, 'test_rec': 0.6636, 'test_loss': 0.9823}
# SAGE	 SAGE_ens_split0.log	 test acc: 0.8546	 stats: {'train_acc': 0.9993, 'val_acc': 0.853, 'test_acc': 0.8546, 'test_f1m': 0.8152, 'test_f1w': 0.8528, 'test_prec': 0.8104, 'test_rec': 0.8224, 'test_loss': 0.7677}
# GT	 GT_ens_split0.log	 test acc: 0.8747	 stats: {'train_acc': 0.9998, 'val_acc': 0.8738, 'test_acc': 0.8747, 'test_f1m': 0.8387, 'test_f1w': 0.8727, 'test_prec': 0.8357, 'test_rec': 0.8441, 'test_loss': 0.597}
# ResNet	 ResNet_ens_split0.log	 test acc: 0.6564	 stats: {'train_acc': 0.7131, 'val_acc': 0.6515, 'test_acc': 0.6564, 'test_f1m': 0.5352, 'test_f1w': 0.6287, 'test_prec': 0.5328, 'test_rec': 0.5726, 'test_loss': 1.0701}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split1.log	 test acc: 0.8796	 stats: {'train_acc': 1.0, 'val_acc': 0.8729, 'test_acc': 0.8796, 'test_f1m': 0.8501, 'test_f1w': 0.8774, 'test_prec': 0.8554, 'test_rec': 0.8477, 'test_loss': 0.5936}
# GAT-sep	 GAT-sep_ens_split1.log	 test acc: 0.8962	 stats: {'train_acc': 1.0, 'val_acc': 0.8927, 'test_acc': 0.8962, 'test_f1m': 0.8727, 'test_f1w': 0.8958, 'test_prec': 0.8711, 'test_rec': 0.8763, 'test_loss': 0.4967}
# GAT	 GAT_ens_split1.log	 test acc: 0.8203	 stats: {'train_acc': 0.9861, 'val_acc': 0.8136, 'test_acc': 0.8203, 'test_f1m': 0.7695, 'test_f1w': 0.8183, 'test_prec': 0.7757, 'test_rec': 0.7708, 'test_loss': 0.6455}
# TAG	 TAG_ens_split1.log	 test acc: 0.881	 stats: {'train_acc': 1.0, 'val_acc': 0.8708, 'test_acc': 0.881, 'test_f1m': 0.8538, 'test_f1w': 0.8798, 'test_prec': 0.8568, 'test_rec': 0.8519, 'test_loss': 0.6117}
# GCN	 GCN_ens_split1.log	 test acc: 0.734	 stats: {'train_acc': 0.9386, 'val_acc': 0.726, 'test_acc': 0.734, 'test_f1m': 0.667, 'test_f1w': 0.7321, 'test_prec': 0.6659, 'test_rec': 0.6763, 'test_loss': 0.8648}
# SAGE	 SAGE_ens_split1.log	 test acc: 0.8652	 stats: {'train_acc': 0.9996, 'val_acc': 0.8628, 'test_acc': 0.8652, 'test_f1m': 0.8286, 'test_f1w': 0.8631, 'test_prec': 0.831, 'test_rec': 0.8282, 'test_loss': 0.7034}
# GT	 GT_ens_split1.log	 test acc: 0.8863	 stats: {'train_acc': 1.0, 'val_acc': 0.8847, 'test_acc': 0.8863, 'test_f1m': 0.8601, 'test_f1w': 0.8847, 'test_prec': 0.8647, 'test_rec': 0.8577, 'test_loss': 0.541}
# ResNet	 ResNet_ens_split1.log	 test acc: 0.6666	 stats: {'train_acc': 0.7202, 'val_acc': 0.6595, 'test_acc': 0.6666, 'test_f1m': 0.5397, 'test_f1w': 0.6385, 'test_prec': 0.548, 'test_rec': 0.5581, 'test_loss': 1.0606}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split2.log	 test acc: 0.8765	 stats: {'train_acc': 1.0, 'val_acc': 0.8628, 'test_acc': 0.8765, 'test_f1m': 0.8468, 'test_f1w': 0.8747, 'test_prec': 0.8488, 'test_rec': 0.8467, 'test_loss': 0.6153}
# GAT-sep	 GAT-sep_ens_split2.log	 test acc: 0.8943	 stats: {'train_acc': 1.0, 'val_acc': 0.8768, 'test_acc': 0.8943, 'test_f1m': 0.8728, 'test_f1w': 0.8942, 'test_prec': 0.87, 'test_rec': 0.8782, 'test_loss': 0.5177}
# GAT	 GAT_ens_split2.log	 test acc: 0.8177	 stats: {'train_acc': 0.9886, 'val_acc': 0.7995, 'test_acc': 0.8177, 'test_f1m': 0.775, 'test_f1w': 0.8164, 'test_prec': 0.7694, 'test_rec': 0.7849, 'test_loss': 0.6236}
# TAG	 TAG_ens_split2.log	 test acc: 0.8735	 stats: {'train_acc': 0.9999, 'val_acc': 0.8609, 'test_acc': 0.8735, 'test_f1m': 0.8419, 'test_f1w': 0.8726, 'test_prec': 0.8426, 'test_rec': 0.8422, 'test_loss': 0.6594}
# GCN	 GCN_ens_split2.log	 test acc: 0.7231	 stats: {'train_acc': 0.9932, 'val_acc': 0.7158, 'test_acc': 0.7231, 'test_f1m': 0.6626, 'test_f1w': 0.7234, 'test_prec': 0.6632, 'test_rec': 0.6677, 'test_loss': 1.0423}
# SAGE	 SAGE_ens_split2.log	 test acc: 0.8593	 stats: {'train_acc': 0.9997, 'val_acc': 0.8487, 'test_acc': 0.8593, 'test_f1m': 0.8235, 'test_f1w': 0.8577, 'test_prec': 0.8239, 'test_rec': 0.8247, 'test_loss': 0.7256}
# GT	 GT_ens_split2.log	 test acc: 0.8839	 stats: {'train_acc': 0.9999, 'val_acc': 0.8708, 'test_acc': 0.8839, 'test_f1m': 0.8568, 'test_f1w': 0.882, 'test_prec': 0.8595, 'test_rec': 0.8561, 'test_loss': 0.5655}
# ResNet	 ResNet_ens_split2.log	 test acc: 0.6627	 stats: {'train_acc': 0.7104, 'val_acc': 0.6542, 'test_acc': 0.6627, 'test_f1m': 0.5317, 'test_f1w': 0.6362, 'test_prec': 0.5504, 'test_rec': 0.5477, 'test_loss': 1.0684}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split3.log	 test acc: 0.875	 stats: {'train_acc': 0.9998, 'val_acc': 0.8773, 'test_acc': 0.875, 'test_f1m': 0.8459, 'test_f1w': 0.8735, 'test_prec': 0.8467, 'test_rec': 0.8466, 'test_loss': 0.613}
# GAT-sep	 GAT-sep_ens_split3.log	 test acc: 0.8938	 stats: {'train_acc': 0.9996, 'val_acc': 0.8911, 'test_acc': 0.8938, 'test_f1m': 0.8702, 'test_f1w': 0.8931, 'test_prec': 0.8672, 'test_rec': 0.8751, 'test_loss': 0.5183}
# GAT	 GAT_ens_split3.log	 test acc: 0.8193	 stats: {'train_acc': 0.989, 'val_acc': 0.8132, 'test_acc': 0.8193, 'test_f1m': 0.7737, 'test_f1w': 0.8186, 'test_prec': 0.7705, 'test_rec': 0.7815, 'test_loss': 0.6263}
# TAG	 TAG_ens_split3.log	 test acc: 0.8705	 stats: {'train_acc': 0.9999, 'val_acc': 0.8641, 'test_acc': 0.8705, 'test_f1m': 0.8409, 'test_f1w': 0.8687, 'test_prec': 0.842, 'test_rec': 0.8413, 'test_loss': 0.6716}
# GCN	 GCN_ens_split3.log	 test acc: 0.737	 stats: {'train_acc': 0.9785, 'val_acc': 0.7211, 'test_acc': 0.737, 'test_f1m': 0.6842, 'test_f1w': 0.737, 'test_prec': 0.684, 'test_rec': 0.6882, 'test_loss': 0.908}
# SAGE	 SAGE_ens_split3.log	 test acc: 0.863	 stats: {'train_acc': 0.999, 'val_acc': 0.8544, 'test_acc': 0.863, 'test_f1m': 0.8302, 'test_f1w': 0.8617, 'test_prec': 0.8279, 'test_rec': 0.8341, 'test_loss': 0.7222}
# GT	 GT_ens_split3.log	 test acc: 0.8828	 stats: {'train_acc': 0.9998, 'val_acc': 0.8854, 'test_acc': 0.8828, 'test_f1m': 0.8566, 'test_f1w': 0.8815, 'test_prec': 0.857, 'test_rec': 0.8579, 'test_loss': 0.5641}
# ResNet	 ResNet_ens_split3.log	 test acc: 0.6661	 stats: {'train_acc': 0.718, 'val_acc': 0.6505, 'test_acc': 0.6661, 'test_f1m': 0.5397, 'test_f1w': 0.6404, 'test_prec': 0.5696, 'test_rec': 0.5541, 'test_loss': 1.0597}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split4.log	 test acc: 0.871	 stats: {'train_acc': 0.9997, 'val_acc': 0.8729, 'test_acc': 0.871, 'test_f1m': 0.8393, 'test_f1w': 0.8685, 'test_prec': 0.837, 'test_rec': 0.844, 'test_loss': 0.6389}
# GAT-sep	 GAT-sep_ens_split4.log	 test acc: 0.8927	 stats: {'train_acc': 0.9999, 'val_acc': 0.8856, 'test_acc': 0.8927, 'test_f1m': 0.8681, 'test_f1w': 0.8916, 'test_prec': 0.8619, 'test_rec': 0.8772, 'test_loss': 0.5315}
# GAT	 GAT_ens_split4.log	 test acc: 0.808	 stats: {'train_acc': 0.9864, 'val_acc': 0.8058, 'test_acc': 0.808, 'test_f1m': 0.753, 'test_f1w': 0.8064, 'test_prec': 0.7475, 'test_rec': 0.7669, 'test_loss': 0.6834}
# TAG	 TAG_ens_split4.log	 test acc: 0.8706	 stats: {'train_acc': 0.9999, 'val_acc': 0.8694, 'test_acc': 0.8706, 'test_f1m': 0.8443, 'test_f1w': 0.869, 'test_prec': 0.8407, 'test_rec': 0.8499, 'test_loss': 0.6899}
# GCN	 GCN_ens_split4.log	 test acc: 0.7215	 stats: {'train_acc': 0.9382, 'val_acc': 0.7207, 'test_acc': 0.7215, 'test_f1m': 0.6489, 'test_f1w': 0.7204, 'test_prec': 0.6503, 'test_rec': 0.6596, 'test_loss': 0.8823}
# SAGE	 SAGE_ens_split4.log	 test acc: 0.8542	 stats: {'train_acc': 0.9996, 'val_acc': 0.8575, 'test_acc': 0.8542, 'test_f1m': 0.8174, 'test_f1w': 0.8517, 'test_prec': 0.8096, 'test_rec': 0.8288, 'test_loss': 0.7497}
# GT	 GT_ens_split4.log	 test acc: 0.8837	 stats: {'train_acc': 0.9998, 'val_acc': 0.8764, 'test_acc': 0.8837, 'test_f1m': 0.8549, 'test_f1w': 0.8819, 'test_prec': 0.8504, 'test_rec': 0.8619, 'test_loss': 0.5867}
# ResNet	 ResNet_ens_split4.log	 test acc: 0.6599	 stats: {'train_acc': 0.7306, 'val_acc': 0.6544, 'test_acc': 0.6599, 'test_f1m': 0.5509, 'test_f1w': 0.6402, 'test_prec': 0.5589, 'test_rec': 0.5797, 'test_loss': 1.101}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split5.log	 test acc: 0.8803	 stats: {'train_acc': 0.9997, 'val_acc': 0.8713, 'test_acc': 0.8803, 'test_f1m': 0.8465, 'test_f1w': 0.8784, 'test_prec': 0.8536, 'test_rec': 0.8431, 'test_loss': 0.5648}
# GAT-sep	 GAT-sep_ens_split5.log	 test acc: 0.9006	 stats: {'train_acc': 0.9998, 'val_acc': 0.884, 'test_acc': 0.9006, 'test_f1m': 0.8731, 'test_f1w': 0.9, 'test_prec': 0.8736, 'test_rec': 0.875, 'test_loss': 0.4785}
# GAT	 GAT_ens_split5.log	 test acc: 0.8173	 stats: {'train_acc': 0.9893, 'val_acc': 0.8094, 'test_acc': 0.8173, 'test_f1m': 0.7656, 'test_f1w': 0.816, 'test_prec': 0.7708, 'test_rec': 0.768, 'test_loss': 0.6215}
# TAG	 TAG_ens_split5.log	 test acc: 0.8851	 stats: {'train_acc': 0.9998, 'val_acc': 0.86, 'test_acc': 0.8851, 'test_f1m': 0.8513, 'test_f1w': 0.8846, 'test_prec': 0.8552, 'test_rec': 0.849, 'test_loss': 0.5613}
# GCN	 GCN_ens_split5.log	 test acc: 0.7314	 stats: {'train_acc': 0.9646, 'val_acc': 0.7197, 'test_acc': 0.7314, 'test_f1m': 0.6691, 'test_f1w': 0.7312, 'test_prec': 0.6752, 'test_rec': 0.6747, 'test_loss': 0.8844}
# SAGE	 SAGE_ens_split5.log	 test acc: 0.872	 stats: {'train_acc': 0.9989, 'val_acc': 0.8503, 'test_acc': 0.872, 'test_f1m': 0.8367, 'test_f1w': 0.8705, 'test_prec': 0.8418, 'test_rec': 0.8335, 'test_loss': 0.6496}
# GT	 GT_ens_split5.log	 test acc: 0.8879	 stats: {'train_acc': 0.9998, 'val_acc': 0.8726, 'test_acc': 0.8879, 'test_f1m': 0.8584, 'test_f1w': 0.8864, 'test_prec': 0.865, 'test_rec': 0.8548, 'test_loss': 0.5019}
# ResNet	 ResNet_ens_split5.log	 test acc: 0.6617	 stats: {'train_acc': 0.7006, 'val_acc': 0.6577, 'test_acc': 0.6617, 'test_f1m': 0.5365, 'test_f1w': 0.6316, 'test_prec': 0.5491, 'test_rec': 0.5704, 'test_loss': 1.0335}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split6.log	 test acc: 0.8713	 stats: {'train_acc': 0.9999, 'val_acc': 0.8625, 'test_acc': 0.8713, 'test_f1m': 0.8424, 'test_f1w': 0.8703, 'test_prec': 0.8436, 'test_rec': 0.8433, 'test_loss': 0.63}
# GAT-sep	 GAT-sep_ens_split6.log	 test acc: 0.895	 stats: {'train_acc': 0.9999, 'val_acc': 0.8801, 'test_acc': 0.895, 'test_f1m': 0.8719, 'test_f1w': 0.8944, 'test_prec': 0.8679, 'test_rec': 0.8798, 'test_loss': 0.5407}
# GAT	 GAT_ens_split6.log	 test acc: 0.8212	 stats: {'train_acc': 0.9884, 'val_acc': 0.7986, 'test_acc': 0.8212, 'test_f1m': 0.7724, 'test_f1w': 0.8191, 'test_prec': 0.7656, 'test_rec': 0.7861, 'test_loss': 0.6192}
# TAG	 TAG_ens_split6.log	 test acc: 0.8752	 stats: {'train_acc': 1.0, 'val_acc': 0.8685, 'test_acc': 0.8752, 'test_f1m': 0.8432, 'test_f1w': 0.8737, 'test_prec': 0.8422, 'test_rec': 0.8452, 'test_loss': 0.6384}
# GCN	 GCN_ens_split6.log	 test acc: 0.7305	 stats: {'train_acc': 0.9819, 'val_acc': 0.7167, 'test_acc': 0.7305, 'test_f1m': 0.672, 'test_f1w': 0.731, 'test_prec': 0.6707, 'test_rec': 0.6771, 'test_loss': 0.9296}
# SAGE	 SAGE_ens_split6.log	 test acc: 0.8595	 stats: {'train_acc': 0.9995, 'val_acc': 0.8535, 'test_acc': 0.8595, 'test_f1m': 0.8202, 'test_f1w': 0.8583, 'test_prec': 0.8159, 'test_rec': 0.8266, 'test_loss': 0.7364}
# GT	 GT_ens_split6.log	 test acc: 0.8835	 stats: {'train_acc': 0.9998, 'val_acc': 0.8764, 'test_acc': 0.8835, 'test_f1m': 0.8557, 'test_f1w': 0.8823, 'test_prec': 0.8543, 'test_rec': 0.8597, 'test_loss': 0.5745}
# ResNet	 ResNet_ens_split6.log	 test acc: 0.6544	 stats: {'train_acc': 0.7251, 'val_acc': 0.6563, 'test_acc': 0.6544, 'test_f1m': 0.5313, 'test_f1w': 0.628, 'test_prec': 0.544, 'test_rec': 0.5544, 'test_loss': 1.0906}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split7.log	 test acc: 0.8682	 stats: {'train_acc': 0.9997, 'val_acc': 0.862, 'test_acc': 0.8682, 'test_f1m': 0.8364, 'test_f1w': 0.8662, 'test_prec': 0.8379, 'test_rec': 0.8372, 'test_loss': 0.6824}
# GAT-sep	 GAT-sep_ens_split7.log	 test acc: 0.8814	 stats: {'train_acc': 0.9996, 'val_acc': 0.8738, 'test_acc': 0.8814, 'test_f1m': 0.8545, 'test_f1w': 0.8808, 'test_prec': 0.8531, 'test_rec': 0.8601, 'test_loss': 0.5739}
# GAT	 GAT_ens_split7.log	 test acc: 0.8214	 stats: {'train_acc': 0.9894, 'val_acc': 0.7979, 'test_acc': 0.8214, 'test_f1m': 0.7691, 'test_f1w': 0.8187, 'test_prec': 0.7662, 'test_rec': 0.7792, 'test_loss': 0.6591}
# TAG	 TAG_ens_split7.log	 test acc: 0.8646	 stats: {'train_acc': 1.0, 'val_acc': 0.8583, 'test_acc': 0.8646, 'test_f1m': 0.8321, 'test_f1w': 0.864, 'test_prec': 0.8319, 'test_rec': 0.8338, 'test_loss': 0.7155}
# GCN	 GCN_ens_split7.log	 test acc: 0.7303	 stats: {'train_acc': 0.9689, 'val_acc': 0.7207, 'test_acc': 0.7303, 'test_f1m': 0.6721, 'test_f1w': 0.7292, 'test_prec': 0.6737, 'test_rec': 0.6766, 'test_loss': 0.9157}
# SAGE	 SAGE_ens_split7.log	 test acc: 0.8607	 stats: {'train_acc': 0.9994, 'val_acc': 0.8489, 'test_acc': 0.8607, 'test_f1m': 0.8226, 'test_f1w': 0.8589, 'test_prec': 0.8221, 'test_rec': 0.8251, 'test_loss': 0.7605}
# GT	 GT_ens_split7.log	 test acc: 0.8766	 stats: {'train_acc': 0.9998, 'val_acc': 0.8726, 'test_acc': 0.8766, 'test_f1m': 0.8477, 'test_f1w': 0.8751, 'test_prec': 0.848, 'test_rec': 0.8493, 'test_loss': 0.6163}
# ResNet	 ResNet_ens_split7.log	 test acc: 0.664	 stats: {'train_acc': 0.7197, 'val_acc': 0.6528, 'test_acc': 0.664, 'test_f1m': 0.5317, 'test_f1w': 0.6327, 'test_prec': 0.5641, 'test_rec': 0.5478, 'test_loss': 1.0816}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split8.log	 test acc: 0.8703	 stats: {'train_acc': 0.9998, 'val_acc': 0.8683, 'test_acc': 0.8703, 'test_f1m': 0.8379, 'test_f1w': 0.8688, 'test_prec': 0.8404, 'test_rec': 0.8374, 'test_loss': 0.6374}
# GAT-sep	 GAT-sep_ens_split8.log	 test acc: 0.8867	 stats: {'train_acc': 0.9998, 'val_acc': 0.8876, 'test_acc': 0.8867, 'test_f1m': 0.8593, 'test_f1w': 0.8859, 'test_prec': 0.8574, 'test_rec': 0.8641, 'test_loss': 0.5296}
# GAT	 GAT_ens_split8.log	 test acc: 0.8177	 stats: {'train_acc': 0.9884, 'val_acc': 0.7936, 'test_acc': 0.8177, 'test_f1m': 0.7657, 'test_f1w': 0.8158, 'test_prec': 0.7652, 'test_rec': 0.7745, 'test_loss': 0.6555}
# TAG	 TAG_ens_split8.log	 test acc: 0.8662	 stats: {'train_acc': 1.0, 'val_acc': 0.8588, 'test_acc': 0.8662, 'test_f1m': 0.8336, 'test_f1w': 0.865, 'test_prec': 0.8307, 'test_rec': 0.8379, 'test_loss': 0.6916}
# GCN	 GCN_ens_split8.log	 test acc: 0.7222	 stats: {'train_acc': 0.959, 'val_acc': 0.7188, 'test_acc': 0.7222, 'test_f1m': 0.6633, 'test_f1w': 0.7238, 'test_prec': 0.6642, 'test_rec': 0.6694, 'test_loss': 0.9019}
# SAGE	 SAGE_ens_split8.log	 test acc: 0.8607	 stats: {'train_acc': 0.9996, 'val_acc': 0.8579, 'test_acc': 0.8607, 'test_f1m': 0.8269, 'test_f1w': 0.8598, 'test_prec': 0.827, 'test_rec': 0.8282, 'test_loss': 0.7425}
# GT	 GT_ens_split8.log	 test acc: 0.8807	 stats: {'train_acc': 0.9999, 'val_acc': 0.8812, 'test_acc': 0.8807, 'test_f1m': 0.8503, 'test_f1w': 0.8796, 'test_prec': 0.8502, 'test_rec': 0.8528, 'test_loss': 0.5641}
# ResNet	 ResNet_ens_split8.log	 test acc: 0.6641	 stats: {'train_acc': 0.7259, 'val_acc': 0.6556, 'test_acc': 0.6641, 'test_f1m': 0.5415, 'test_f1w': 0.6426, 'test_prec': 0.5461, 'test_rec': 0.5654, 'test_loss': 1.0742}
#
# ====================================================================================================
#
# GT-sep	 GT-sep_ens_split9.log	 test acc: 0.875	 stats: {'train_acc': 0.9996, 'val_acc': 0.8634, 'test_acc': 0.875, 'test_f1m': 0.8428, 'test_f1w': 0.8731, 'test_prec': 0.8442, 'test_rec': 0.8428, 'test_loss': 0.6315}
# GAT-sep	 GAT-sep_ens_split9.log	 test acc: 0.8923	 stats: {'train_acc': 0.9996, 'val_acc': 0.8865, 'test_acc': 0.8923, 'test_f1m': 0.8666, 'test_f1w': 0.8914, 'test_prec': 0.8607, 'test_rec': 0.8754, 'test_loss': 0.5375}
# GAT	 GAT_ens_split9.log	 test acc: 0.817	 stats: {'train_acc': 0.9894, 'val_acc': 0.8099, 'test_acc': 0.817, 'test_f1m': 0.7661, 'test_f1w': 0.8141, 'test_prec': 0.7601, 'test_rec': 0.7796, 'test_loss': 0.6595}
# TAG	 TAG_ens_split9.log	 test acc: 0.8747	 stats: {'train_acc': 0.9998, 'val_acc': 0.8706, 'test_acc': 0.8747, 'test_f1m': 0.8413, 'test_f1w': 0.8735, 'test_prec': 0.8366, 'test_rec': 0.8472, 'test_loss': 0.6403}
# GCN	 GCN_ens_split9.log	 test acc: 0.7243	 stats: {'train_acc': 0.9785, 'val_acc': 0.7222, 'test_acc': 0.7243, 'test_f1m': 0.662, 'test_f1w': 0.7246, 'test_prec': 0.6608, 'test_rec': 0.6694, 'test_loss': 0.9564}
# SAGE	 SAGE_ens_split9.log	 test acc: 0.8551	 stats: {'train_acc': 0.9995, 'val_acc': 0.8523, 'test_acc': 0.8551, 'test_f1m': 0.8142, 'test_f1w': 0.8533, 'test_prec': 0.8071, 'test_rec': 0.8245, 'test_loss': 0.761}
# GT	 GT_ens_split9.log	 test acc: 0.8809	 stats: {'train_acc': 0.9995, 'val_acc': 0.878, 'test_acc': 0.8809, 'test_f1m': 0.8507, 'test_f1w': 0.879, 'test_prec': 0.8505, 'test_rec': 0.8525, 'test_loss': 0.5835}
# ResNet	 ResNet_ens_split9.log	 test acc: 0.6581	 stats: {'train_acc': 0.7149, 'val_acc': 0.6528, 'test_acc': 0.6581, 'test_f1m': 0.5261, 'test_f1w': 0.626, 'test_prec': 0.5541, 'test_rec': 0.5477, 'test_loss': 1.0972}
#
# ====================================================================================================

# %%
keys = sorted(list(model2scores.keys()))

# %%
import numpy as np

for key in keys:
    values = model2scores[key]
    print(f"{key}: \t{np.mean(values)*100:.3f} +- {np.std(values)*100:.3f}")
    if 'TABM' in key:
        print()
# Out:
# GAT-sep_BASE: 	88.368 +- 0.518
# GAT-sep_ENS: 	89.176 +- 0.552
# GAT-sep_TABM: 	89.131 +- 0.438
#
# GAT_BASE: 	80.386 +- 0.650
# GAT_ENS: 	81.666 +- 0.490
# GAT_TABM: 	79.130 +- 0.463
#
# GCN_BASE: 	71.106 +- 0.696
# GCN_ENS: 	72.770 +- 0.530
# GCN_TABM: 	75.683 +- 0.662
#
# GT-sep_BASE: 	86.633 +- 0.548
# GT-sep_ENS: 	87.366 +- 0.404
# GT-sep_TABM: 	88.360 +- 0.521
#
# GT_BASE: 	87.394 +- 0.547
# GT_ENS: 	88.210 +- 0.385
# GT_TABM: 	88.657 +- 0.228
#
# ResNet_BASE: 	65.926 +- 0.437
# ResNet_ENS: 	66.140 +- 0.390
# ResNet_TABM: 	65.910 +- 0.488
#
# SAGE_BASE: 	85.258 +- 0.586
# SAGE_ENS: 	86.043 +- 0.516
# SAGE_TABM: 	87.444 +- 0.501
#
# TAG_BASE: 	86.403 +- 0.528
# TAG_ENS: 	87.262 +- 0.643
# TAG_TABM: 	87.492 +- 0.511

# %%
import pandas as pd
import re
from pathlib import Path

models = ['GT-sep', 'GAT-sep', 'GAT', 'GCN', 'SAGE', 'GT', 'ResNet']
# models = ['GT-sep', 'GAT-sep', 'GAT', 'GCN', 'SAGE', 'GT', 'ResNet', 'TAG']

root = Path('.')
roman_ens_path = root / 'logs_ensemble'
if not roman_ens_path.exists():
    roman_ens_path = root / 'roman_empire' / 'logs_ensemble'

dataset_log_dirs = {
    'roman_empire': {
        'BASE': root / 'roman_empire' / 'logs_base',
        # 'ENS': roman_ens_path,
        'TABM': root / 'roman_empire' / 'logs_tabm',
    },
    'amazon_ratings': {
        'BASE': root / 'results' / 'amazon_ratings' / 'logs_base',
        # 'ENS': root / 'results' / 'amazon_ratings' / 'logs_ensemble',
        'TABM': root / 'results' / 'amazon_ratings' / 'logs_tabm',
    },
    'minesweeper': {
        'BASE': root / 'results' / 'minesweeper' / 'logs_base',
        # 'ENS': root / 'results' / 'minesweeper' / 'logs_ensemble',
        'TABM': root / 'results' / 'minesweeper' / 'logs_tabm',
    },
    'questions': {
        'BASE': root / 'results' / 'questions' / 'logs_base',
        # 'ENS': root / 'results' / 'questions' / 'logs_ensemble',
        'TABM': root / 'results' / 'questions' / 'logs_tabm',
    },
    'tolokers': {
        'BASE': root / 'results' / 'tolokers' / 'logs_base',
        # 'ENS': root / 'results' / 'tolokers' / 'logs_ensemble',
        'TABM': root / 'results' / 'tolokers' / 'logs_tabm',
    },
}

def parse_scores(log_file):
    with open(log_file, 'r') as f:
        content = f.read()

    val_match = re.search(r'val_acc=([\d.]+)', content)
    test_acc_match = re.search(r'test_acc=([\d.]+)', content)

    return {
        'val_acc': float(val_match.group(1)) if val_match else None,
        'test_acc': float(test_acc_match.group(1)) if test_acc_match else None,
    }

rows = []
for dataset_name, method2dir in dataset_log_dirs.items():
    for method_name, logs_dir in method2dir.items():
        if not logs_dir.exists():
            continue

        all_files = [x.name for x in logs_dir.iterdir() if x.is_file() and x.suffix == '.log']

        for model in models:
            split_scores = []
            for split in range(10):
                files = [
                    x for x in all_files
                    if f'{model}_' in x and f'split{split}' in x
                ]

                # Match notebook logic for BASE: evaluate only 5-layer runs.
                if method_name == 'BASE':
                    files = [x for x in files if '_5L_' in x]

                if not files:
                    continue

                best_val = -1.0
                best_test_acc = None

                for file_name in files:
                    score = parse_scores(logs_dir / file_name)
                    val_acc = score['val_acc']
                    if val_acc is None:
                        continue
                    if val_acc > best_val:
                        best_val = val_acc
                        best_test_acc = score['test_acc']

                if best_test_acc is not None:
                    split_scores.append(best_test_acc)

            if split_scores:
                rows.append({
                    'model_variant': f'{model}_{method_name}',
                    'dataset': dataset_name,
                    'mean_acc': float(pd.Series(split_scores).mean()),
                    'std_acc': float(pd.Series(split_scores).std(ddof=0)),
                })

mx_mean = pd.DataFrame(rows).pivot_table(
    index='model_variant',
    columns='dataset',
    values='mean_acc',
    aggfunc='mean',
).sort_index().mul(100)

mx_std = pd.DataFrame(rows).pivot_table(
    index='model_variant',
    columns='dataset',
    values='std_acc',
    aggfunc='mean',
).reindex(mx_mean.index).mul(100)

mx_dataset = mx_mean.round(3)

mx_text = mx_mean.round(3).astype(str) + ' ± ' + mx_std.round(3).astype(str)

def highlight_top2(col):
    styles = ['' for _ in col]
    non_na = col.dropna()
    if non_na.empty:
        return styles

    unique_vals = sorted(non_na.unique(), reverse=True)
    best = unique_vals[0]
    second = unique_vals[1] if len(unique_vals) > 1 else None

    for i, v in enumerate(col):
        if pd.isna(v):
            continue
        if v == best:
            styles[i] = 'background-color: #ffd700; font-weight: 700'  # gold
        elif second is not None and v == second:
            styles[i] = 'background-color: #c0c0c0; font-weight: 700'  # silver
    return styles

mx_text.style.apply(lambda col: highlight_top2(mx_mean[col.name]), axis=0)
# Out:
# <style type="text/css">
# #T_f5dae_row1_col1, #T_f5dae_row1_col3, #T_f5dae_row3_col2, #T_f5dae_row4_col4, #T_f5dae_row8_col0 {
#   background-color: #ffd700;
#   font-weight: 700;
# }
# #T_f5dae_row3_col4, #T_f5dae_row5_col2, #T_f5dae_row6_col0, #T_f5dae_row9_col3, #T_f5dae_row12_col1 {
#   background-color: #c0c0c0;
#   font-weight: 700;
# }
# </style>
# <table id="T_f5dae">
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_f5dae_level0_col0" class="col_heading level0 col0" >amazon_ratings</th>
#       <th id="T_f5dae_level0_col1" class="col_heading level0 col1" >minesweeper</th>
#       <th id="T_f5dae_level0_col2" class="col_heading level0 col2" >questions</th>
#       <th id="T_f5dae_level0_col3" class="col_heading level0 col3" >roman_empire</th>
#       <th id="T_f5dae_level0_col4" class="col_heading level0 col4" >tolokers</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_variant</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5dae_level0_row0" class="row_heading level0 row0" >GAT-sep_BASE</th>
#       <td id="T_f5dae_row0_col0" class="data row0 col0" >52.593 ± 0.344</td>
#       <td id="T_f5dae_row0_col1" class="data row0 col1" >88.356 ± 0.643</td>
#       <td id="T_f5dae_row0_col2" class="data row0 col2" >93.98 ± 1.565</td>
#       <td id="T_f5dae_row0_col3" class="data row0 col3" >88.368 ± 0.518</td>
#       <td id="T_f5dae_row0_col4" class="data row0 col4" >79.868 ± 0.519</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row1" class="row_heading level0 row1" >GAT-sep_TABM</th>
#       <td id="T_f5dae_row1_col0" class="data row1 col0" >49.927 ± 0.787</td>
#       <td id="T_f5dae_row1_col1" class="data row1 col1" >88.6 ± 0.421</td>
#       <td id="T_f5dae_row1_col2" class="data row1 col2" >95.658 ± 0.237</td>
#       <td id="T_f5dae_row1_col3" class="data row1 col3" >89.131 ± 0.438</td>
#       <td id="T_f5dae_row1_col4" class="data row1 col4" >81.142 ± 0.718</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row2" class="row_heading level0 row2" >GAT_BASE</th>
#       <td id="T_f5dae_row2_col0" class="data row2 col0" >47.64 ± 0.674</td>
#       <td id="T_f5dae_row2_col1" class="data row2 col1" >87.144 ± 0.528</td>
#       <td id="T_f5dae_row2_col2" class="data row2 col2" >96.899 ± 0.232</td>
#       <td id="T_f5dae_row2_col3" class="data row2 col3" >80.386 ± 0.65</td>
#       <td id="T_f5dae_row2_col4" class="data row2 col4" >79.453 ± 1.037</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row3" class="row_heading level0 row3" >GAT_TABM</th>
#       <td id="T_f5dae_row3_col0" class="data row3 col0" >47.598 ± 0.534</td>
#       <td id="T_f5dae_row3_col1" class="data row3 col1" >86.072 ± 0.612</td>
#       <td id="T_f5dae_row3_col2" class="data row3 col2" >97.159 ± 0.073</td>
#       <td id="T_f5dae_row3_col3" class="data row3 col3" >79.13 ± 0.463</td>
#       <td id="T_f5dae_row3_col4" class="data row3 col4" >81.156 ± 0.972</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row4" class="row_heading level0 row4" >GCN_BASE</th>
#       <td id="T_f5dae_row4_col0" class="data row4 col0" >47.841 ± 0.771</td>
#       <td id="T_f5dae_row4_col1" class="data row4 col1" >84.868 ± 0.49</td>
#       <td id="T_f5dae_row4_col2" class="data row4 col2" >96.746 ± 0.315</td>
#       <td id="T_f5dae_row4_col3" class="data row4 col3" >71.106 ± 0.696</td>
#       <td id="T_f5dae_row4_col4" class="data row4 col4" >81.23 ± 0.713</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row5" class="row_heading level0 row5" >GCN_TABM</th>
#       <td id="T_f5dae_row5_col0" class="data row5 col0" >48.082 ± 0.651</td>
#       <td id="T_f5dae_row5_col1" class="data row5 col1" >84.44 ± 0.598</td>
#       <td id="T_f5dae_row5_col2" class="data row5 col2" >97.112 ± 0.073</td>
#       <td id="T_f5dae_row5_col3" class="data row5 col3" >75.683 ± 0.662</td>
#       <td id="T_f5dae_row5_col4" class="data row5 col4" >81.105 ± 0.477</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row6" class="row_heading level0 row6" >GT-sep_BASE</th>
#       <td id="T_f5dae_row6_col0" class="data row6 col0" >52.598 ± 0.443</td>
#       <td id="T_f5dae_row6_col1" class="data row6 col1" >87.304 ± 0.532</td>
#       <td id="T_f5dae_row6_col2" class="data row6 col2" >96.704 ± 0.361</td>
#       <td id="T_f5dae_row6_col3" class="data row6 col3" >86.633 ± 0.548</td>
#       <td id="T_f5dae_row6_col4" class="data row6 col4" >77.668 ± 1.554</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row7" class="row_heading level0 row7" >GT-sep_TABM</th>
#       <td id="T_f5dae_row7_col0" class="data row7 col0" >50.323 ± 0.635</td>
#       <td id="T_f5dae_row7_col1" class="data row7 col1" >87.18 ± 0.516</td>
#       <td id="T_f5dae_row7_col2" class="data row7 col2" >96.308 ± 0.24</td>
#       <td id="T_f5dae_row7_col3" class="data row7 col3" >88.36 ± 0.521</td>
#       <td id="T_f5dae_row7_col4" class="data row7 col4" >79.85 ± 0.602</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row8" class="row_heading level0 row8" >GT_BASE</th>
#       <td id="T_f5dae_row8_col0" class="data row8 col0" >52.698 ± 0.561</td>
#       <td id="T_f5dae_row8_col1" class="data row8 col1" >87.532 ± 0.323</td>
#       <td id="T_f5dae_row8_col2" class="data row8 col2" >96.278 ± 0.609</td>
#       <td id="T_f5dae_row8_col3" class="data row8 col3" >87.394 ± 0.547</td>
#       <td id="T_f5dae_row8_col4" class="data row8 col4" >78.085 ± 1.51</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row9" class="row_heading level0 row9" >GT_TABM</th>
#       <td id="T_f5dae_row9_col0" class="data row9 col0" >49.839 ± 0.772</td>
#       <td id="T_f5dae_row9_col1" class="data row9 col1" >87.56 ± 0.627</td>
#       <td id="T_f5dae_row9_col2" class="data row9 col2" >95.426 ± 0.61</td>
#       <td id="T_f5dae_row9_col3" class="data row9 col3" >88.657 ± 0.228</td>
#       <td id="T_f5dae_row9_col4" class="data row9 col4" >80.163 ± 1.098</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row10" class="row_heading level0 row10" >ResNet_BASE</th>
#       <td id="T_f5dae_row10_col0" class="data row10 col0" >45.847 ± 0.489</td>
#       <td id="T_f5dae_row10_col1" class="data row10 col1" >80.0 ± 0.0</td>
#       <td id="T_f5dae_row10_col2" class="data row10 col2" >96.708 ± 0.524</td>
#       <td id="T_f5dae_row10_col3" class="data row10 col3" >65.926 ± 0.437</td>
#       <td id="T_f5dae_row10_col4" class="data row10 col4" >78.141 ± 0.218</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row11" class="row_heading level0 row11" >ResNet_TABM</th>
#       <td id="T_f5dae_row11_col0" class="data row11 col0" >40.352 ± 0.749</td>
#       <td id="T_f5dae_row11_col1" class="data row11 col1" >80.0 ± 0.0</td>
#       <td id="T_f5dae_row11_col2" class="data row11 col2" >97.07 ± 0.095</td>
#       <td id="T_f5dae_row11_col3" class="data row11 col3" >65.91 ± 0.488</td>
#       <td id="T_f5dae_row11_col4" class="data row11 col4" >77.841 ± 0.557</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row12" class="row_heading level0 row12" >SAGE_BASE</th>
#       <td id="T_f5dae_row12_col0" class="data row12 col0" >52.01 ± 0.678</td>
#       <td id="T_f5dae_row12_col1" class="data row12 col1" >88.36 ± 0.516</td>
#       <td id="T_f5dae_row12_col2" class="data row12 col2" >95.393 ± 0.618</td>
#       <td id="T_f5dae_row12_col3" class="data row12 col3" >85.258 ± 0.586</td>
#       <td id="T_f5dae_row12_col4" class="data row12 col4" >80.722 ± 0.309</td>
#     </tr>
#     <tr>
#       <th id="T_f5dae_level0_row13" class="row_heading level0 row13" >SAGE_TABM</th>
#       <td id="T_f5dae_row13_col0" class="data row13 col0" >49.2 ± 0.761</td>
#       <td id="T_f5dae_row13_col1" class="data row13 col1" >88.26 ± 0.7</td>
#       <td id="T_f5dae_row13_col2" class="data row13 col2" >96.083 ± 0.27</td>
#       <td id="T_f5dae_row13_col3" class="data row13 col3" >87.444 ± 0.501</td>
#       <td id="T_f5dae_row13_col4" class="data row13 col4" >80.452 ± 0.606</td>
